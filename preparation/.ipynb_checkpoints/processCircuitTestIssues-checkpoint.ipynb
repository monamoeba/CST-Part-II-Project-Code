# %%
import sys
import os
# Add the parent directory to the Python path
os.chdir('..')
print(os.getcwd())
# Out:
# C:\Users\monam\OneDrive\Desktop\UNI\II\PartIIProject\CST-Part-II-Project-Code

# %%
from src.simulator.qccd_circuit import process_circuit

ds = [3,5,7]

for d in ds: 
    print(process_circuit(d,2,[1.0],100_000)) 
    #print(process_circuit_wise_arch(d,c,[1.0], 100_000)) 
    print('\n')
# Out:
# {'ElapsedTime': {'Forwarding': 0.004085000000000001}, 'Operations': {'Forwarding': 466}, 'MeanConcurrency': {'Forwarding': np.float64(6.781818181818182)}, 'QubitOperations': {'Forwarding': 178}, 'LogicalErrorRates': {'Forwarding': [0.05569]}, 'PhysicalZErrorRates': {'Forwarding': [np.float64(0.006711326100063682)]}, 'PhysicalXErrorRates': {'Forwarding': [np.float64(0.006163226932548814)]}, 'Electrodes': {'Forwarding': 980}, 'DACs': {'Forwarding': 980}, 'Capacity': 2, 'Distance': 3}
#
#
# {'ElapsedTime': {'Forwarding': 0.004085000000000001}, 'Operations': {'Forwarding': 1530}, 'MeanConcurrency': {'Forwarding': np.float64(20.115151515151513)}, 'QubitOperations': {'Forwarding': 570}, 'LogicalErrorRates': {'Forwarding': [0.02028]}, 'PhysicalZErrorRates': {'Forwarding': [np.float64(0.007041585573227546)]}, 'PhysicalXErrorRates': {'Forwarding': [np.float64(0.006418054713602888)]}, 'Electrodes': {'Forwarding': 2800}, 'DACs': {'Forwarding': 2800}, 'Capacity': 2, 'Distance': 5}
#
#
# {'ElapsedTime': {'Forwarding': 0.004080000000000001}, 'Operations': {'Forwarding': 3194}, 'MeanConcurrency': {'Forwarding': np.float64(39.66257668711656)}, 'QubitOperations': {'Forwarding': 1178}, 'LogicalErrorRates': {'Forwarding': [0.01262]}, 'PhysicalZErrorRates': {'Forwarding': [np.float64(0.007176006624135872)]}, 'PhysicalXErrorRates': {'Forwarding': [np.float64(0.006528395848468784)]}, 'Electrodes': {'Forwarding': 5500}, 'DACs': {'Forwarding': 5500}, 'Capacity': 2, 'Distance': 7}

# %%
from src.simulator.qccd_circuit import *
from src.color_code_utils.color_code_circuits.color_code_circuit_666 import *

# testing the color code versions
ds = [5]
"""
for d in ds:
    print(process_color_code_circuit(d,2,[1.0],100_000, (6,6,6)))
    print('\n')
"""
#ccobj = ColorCodeCircuit666(3,2)
qccd = QCCDCircuit.generate_color_code(5,2,(6,6,6))
print(f'before circuitString: {qccd}')
print(f'after circuitString: {qccd.circuitString()}')
print(qccd.dataQubitsIdxs)
qccd._parseCircuitString(qccd.dataQubitsIdxs)
print(qccd._measurementIons)
print(qccd._dataIons)
print(qccd._ionMapping)
#the measurement qubits aren't being picked up for some reason
# Out:
# before circuitString: QUBIT_COORDS(0, 0) 0
# QUBIT_COORDS(1, 1) 1
# QUBIT_COORDS(2, 0) 2
# QUBIT_COORDS(2, 2) 3
# QUBIT_COORDS(3, 1) 4
# QUBIT_COORDS(3, 3) 5
# QUBIT_COORDS(4, 0) 6
# QUBIT_COORDS(4, 2) 7
# QUBIT_COORDS(4, 4) 8
# QUBIT_COORDS(5, 1) 9
# QUBIT_COORDS(5, 3) 10
# QUBIT_COORDS(5, 5) 11
# QUBIT_COORDS(6, 0) 12
# QUBIT_COORDS(6, 2) 13
# QUBIT_COORDS(6, 4) 14
# QUBIT_COORDS(6, 6) 15
# QUBIT_COORDS(7, 1) 16
# QUBIT_COORDS(7, 3) 17
# QUBIT_COORDS(7, 5) 18
# QUBIT_COORDS(8, 0) 19
# QUBIT_COORDS(8, 2) 20
# QUBIT_COORDS(8, 4) 21
# QUBIT_COORDS(9, 1) 22
# QUBIT_COORDS(9, 3) 23
# QUBIT_COORDS(10, 0) 24
# QUBIT_COORDS(10, 2) 25
# QUBIT_COORDS(11, 1) 26
# QUBIT_COORDS(12, 0) 27
# R 4 9 19 3 13 27 5 10 20 22 26 14 11 21 23 0 2 12 15 8 6 16 1 7 17 24 18 25
# TICK
# RX 6 24 1 16 7 25 17 8 18
# CX 1 0 16 12 7 4 25 22 17 13 8 5 18 14
# TICK
# CX 1 2 16 19 7 9 25 26 17 20 8 10 18 21
# TICK
# CX 6 2 24 19 16 9 7 3 25 20 17 10 18 11
# TICK
# CX 6 12 24 27 1 4 16 22 7 13 17 23 8 14
# TICK
# CX 6 4 24 22 16 13 7 5 25 23 17 14 18 15
# TICK
# CX 6 9 24 26 1 3 16 20 7 10 17 21 8 11
# TICK
# MX 6 24 1 16 7 25 17 8 18
# R 6 24 1 16 7 25 17 8 18
# CX 0 1 12 16 4 7 22 25 13 17 5 8 14 18
# TICK
# CX 2 1 19 16 9 7 26 25 20 17 10 8 21 18
# TICK
# CX 2 6 19 24 9 16 3 7 20 25 10 17 11 18
# TICK
# CX 12 6 27 24 4 1 22 16 13 7 23 17 14 8
# TICK
# CX 4 6 22 24 13 16 5 7 23 25 14 17 15 18
# TICK
# CX 9 6 26 24 3 1 20 16 10 7 21 17 11 8
# TICK
# M 6 24 1 16 7 25 17 8 18
# DETECTOR(4, 0, 1, 3) rec[-9]
# DETECTOR(10, 0, 1, 3) rec[-8]
# DETECTOR(1, 1, 1, 4) rec[-7]
# DETECTOR(7, 1, 1, 4) rec[-6]
# DETECTOR(4, 2, 1, 5) rec[-5]
# DETECTOR(10, 2, 1, 5) rec[-4]
# DETECTOR(7, 3, 1, 3) rec[-3]
# DETECTOR(4, 4, 1, 4) rec[-2]
# DETECTOR(7, 5, 1, 5) rec[-1]
# TICK
# SHIFT_COORDS(0, 0, 1)
# RX 6 24 1 16 7 25 17 8 18
# CX 1 0 16 12 7 4 25 22 17 13 8 5 18 14
# TICK
# CX 1 2 16 19 7 9 25 26 17 20 8 10 18 21
# TICK
# CX 6 2 24 19 16 9 7 3 25 20 17 10 18 11
# TICK
# CX 6 12 24 27 1 4 16 22 7 13 17 23 8 14
# TICK
# CX 6 4 24 22 16 13 7 5 25 23 17 14 18 15
# TICK
# CX 6 9 24 26 1 3 16 20 7 10 17 21 8 11
# TICK
# MX 6 24 1 16 7 25 17 8 18
# DETECTOR(4, 0, 0, 0) rec[-9] rec[-27]
# DETECTOR(10, 0, 0, 0) rec[-8] rec[-26]
# DETECTOR(1, 1, 0, 1) rec[-7] rec[-25]
# DETECTOR(7, 1, 0, 1) rec[-6] rec[-24]
# DETECTOR(4, 2, 0, 2) rec[-5] rec[-23]
# DETECTOR(10, 2, 0, 2) rec[-4] rec[-22]
# DETECTOR(7, 3, 0, 0) rec[-3] rec[-21]
# DETECTOR(4, 4, 0, 1) rec[-2] rec[-20]
# DETECTOR(7, 5, 0, 2) rec[-1] rec[-19]
# TICK
# R 6 24 1 16 7 25 17 8 18
# CX 0 1 12 16 4 7 22 25 13 17 5 8 14 18
# TICK
# CX 2 1 19 16 9 7 26 25 20 17 10 8 21 18
# TICK
# CX 2 6 19 24 9 16 3 7 20 25 10 17 11 18
# TICK
# CX 12 6 27 24 4 1 22 16 13 7 23 17 14 8
# TICK
# CX 4 6 22 24 13 16 5 7 23 25 14 17 15 18
# TICK
# CX 9 6 26 24 3 1 20 16 10 7 21 17 11 8
# TICK
# M 6 24 1 16 7 25 17 8 18
# DETECTOR(4, 0, 1, 3) rec[-9] rec[-27]
# DETECTOR(10, 0, 1, 3) rec[-8] rec[-26]
# DETECTOR(1, 1, 1, 4) rec[-7] rec[-25]
# DETECTOR(7, 1, 1, 4) rec[-6] rec[-24]
# DETECTOR(4, 2, 1, 5) rec[-5] rec[-23]
# DETECTOR(10, 2, 1, 5) rec[-4] rec[-22]
# DETECTOR(7, 3, 1, 3) rec[-3] rec[-21]
# DETECTOR(4, 4, 1, 4) rec[-2] rec[-20]
# DETECTOR(7, 5, 1, 5) rec[-1] rec[-19]
# TICK
# SHIFT_COORDS(0, 0, 1)
# M 0 2 3 4 5 9 10 11 12 13 14 15 19 20 21 22 23 26 27
# DETECTOR(4, 0, 1, 3) rec[-11] rec[-14] rec[-16] rec[-18] rec[-28]
# DETECTOR(10, 0, 1, 3) rec[-1] rec[-2] rec[-4] rec[-7] rec[-27]
# DETECTOR(1, 1, 1, 4) rec[-19] rec[-18] rec[-16] rec[-17] rec[-26]
# DETECTOR(7, 1, 1, 4) rec[-11] rec[-7] rec[-4] rec[-6] rec[-10] rec[-14] rec[-25]
# DETECTOR(4, 2, 1, 5) rec[-16] rec[-14] rec[-10] rec[-13] rec[-15] rec[-17] rec[-24]
# DETECTOR(10, 2, 1, 5) rec[-4] rec[-2] rec[-3] rec[-6] rec[-23]
# DETECTOR(7, 3, 1, 3) rec[-10] rec[-6] rec[-3] rec[-5] rec[-9] rec[-13] rec[-22]
# DETECTOR(4, 4, 1, 4) rec[-15] rec[-13] rec[-9] rec[-12] rec[-21]
# DETECTOR(7, 5, 1, 5) rec[-9] rec[-5] rec[-8] rec[-12] rec[-20]
# OBSERVABLE_INCLUDE(0) rec[-19] rec[-18] rec[-11] rec[-7] rec[-1]
# after circuitString: ['QUBIT_COORDS(0, 0) 0', 'QUBIT_COORDS(1, 1) 1', 'QUBIT_COORDS(2, 0) 2', 'QUBIT_COORDS(2, 2) 3', 'QUBIT_COORDS(3, 1) 4', 'QUBIT_COORDS(3, 3) 5', 'QUBIT_COORDS(4, 0) 6', 'QUBIT_COORDS(4, 2) 7', 'QUBIT_COORDS(4, 4) 8', 'QUBIT_COORDS(5, 1) 9', 'QUBIT_COORDS(5, 3) 10', 'QUBIT_COORDS(5, 5) 11', 'QUBIT_COORDS(6, 0) 12', 'QUBIT_COORDS(6, 2) 13', 'QUBIT_COORDS(6, 4) 14', 'QUBIT_COORDS(6, 6) 15', 'QUBIT_COORDS(7, 1) 16', 'QUBIT_COORDS(7, 3) 17', 'QUBIT_COORDS(7, 5) 18', 'QUBIT_COORDS(8, 0) 19', 'QUBIT_COORDS(8, 2) 20', 'QUBIT_COORDS(8, 4) 21', 'QUBIT_COORDS(9, 1) 22', 'QUBIT_COORDS(9, 3) 23', 'QUBIT_COORDS(10, 0) 24', 'QUBIT_COORDS(10, 2) 25', 'QUBIT_COORDS(11, 1) 26', 'QUBIT_COORDS(12, 0) 27', 'R 4', 'R 9', 'R 19', 'R 3', 'R 13', 'R 27', 'R 5', 'R 10', 'R 20', 'R 22', 'R 26', 'R 14', 'R 11', 'R 21', 'R 23', 'R 0', 'R 2', 'R 12', 'R 15', 'R 8', 'R 6', 'R 16', 'R 1', 'R 7', 'R 17', 'R 24', 'R 18', 'R 25', 'R 6', 'R 24', 'R 1', 'R 16', 'R 7', 'R 25', 'R 17', 'R 8', 'R 18', 'H 6', 'H 24', 'H 1', 'H 16', 'H 7', 'H 25', 'H 17', 'H 8', 'H 18', 'CNOT 1 0', 'CNOT 16 12', 'CNOT 7 4', 'CNOT 25 22', 'CNOT 17 13', 'CNOT 8 5', 'CNOT 18 14', 'BARRIER', 'CNOT 1 2', 'CNOT 16 19', 'CNOT 7 9', 'CNOT 25 26', 'CNOT 17 20', 'CNOT 8 10', 'CNOT 18 21', 'BARRIER', 'CNOT 6 2', 'CNOT 24 19', 'CNOT 16 9', 'CNOT 7 3', 'CNOT 25 20', 'CNOT 17 10', 'CNOT 18 11', 'BARRIER', 'CNOT 6 12', 'CNOT 24 27', 'CNOT 1 4', 'CNOT 16 22', 'CNOT 7 13', 'CNOT 17 23', 'CNOT 8 14', 'BARRIER', 'CNOT 6 4', 'CNOT 24 22', 'CNOT 16 13', 'CNOT 7 5', 'CNOT 25 23', 'CNOT 17 14', 'CNOT 18 15', 'BARRIER', 'CNOT 6 9', 'CNOT 24 26', 'CNOT 1 3', 'CNOT 16 20', 'CNOT 7 10', 'CNOT 17 21', 'CNOT 8 11', 'BARRIER', 'H 6', 'H 24', 'H 1', 'H 16', 'H 7', 'H 25', 'H 17', 'H 8', 'H 18', 'M 6', 'M 24', 'M 1', 'M 16', 'M 7', 'M 25', 'M 17', 'M 8', 'M 18', 'H 6', 'H 24', 'H 1', 'H 16', 'H 7', 'H 25', 'H 17', 'H 8', 'H 18', 'R 6', 'R 24', 'R 1', 'R 16', 'R 7', 'R 25', 'R 17', 'R 8', 'R 18', 'CNOT 0 1', 'CNOT 12 16', 'CNOT 4 7', 'CNOT 22 25', 'CNOT 13 17', 'CNOT 5 8', 'CNOT 14 18', 'BARRIER', 'CNOT 2 1', 'CNOT 19 16', 'CNOT 9 7', 'CNOT 26 25', 'CNOT 20 17', 'CNOT 10 8', 'CNOT 21 18', 'BARRIER', 'CNOT 2 6', 'CNOT 19 24', 'CNOT 9 16', 'CNOT 3 7', 'CNOT 20 25', 'CNOT 10 17', 'CNOT 11 18', 'BARRIER', 'CNOT 12 6', 'CNOT 27 24', 'CNOT 4 1', 'CNOT 22 16', 'CNOT 13 7', 'CNOT 23 17', 'CNOT 14 8', 'BARRIER', 'CNOT 4 6', 'CNOT 22 24', 'CNOT 13 16', 'CNOT 5 7', 'CNOT 23 25', 'CNOT 14 17', 'CNOT 15 18', 'BARRIER', 'CNOT 9 6', 'CNOT 26 24', 'CNOT 3 1', 'CNOT 20 16', 'CNOT 10 7', 'CNOT 21 17', 'CNOT 11 8', 'BARRIER', 'M 6', 'M 24', 'M 1', 'M 16', 'M 7', 'M 25', 'M 17', 'M 8', 'M 18', 'R 6', 'R 24', 'R 1', 'R 16', 'R 7', 'R 25', 'R 17', 'R 8', 'R 18', 'H 6', 'H 24', 'H 1', 'H 16', 'H 7', 'H 25', 'H 17', 'H 8', 'H 18', 'CNOT 1 0', 'CNOT 16 12', 'CNOT 7 4', 'CNOT 25 22', 'CNOT 17 13', 'CNOT 8 5', 'CNOT 18 14', 'BARRIER', 'CNOT 1 2', 'CNOT 16 19', 'CNOT 7 9', 'CNOT 25 26', 'CNOT 17 20', 'CNOT 8 10', 'CNOT 18 21', 'BARRIER', 'CNOT 6 2', 'CNOT 24 19', 'CNOT 16 9', 'CNOT 7 3', 'CNOT 25 20', 'CNOT 17 10', 'CNOT 18 11', 'BARRIER', 'CNOT 6 12', 'CNOT 24 27', 'CNOT 1 4', 'CNOT 16 22', 'CNOT 7 13', 'CNOT 17 23', 'CNOT 8 14', 'BARRIER', 'CNOT 6 4', 'CNOT 24 22', 'CNOT 16 13', 'CNOT 7 5', 'CNOT 25 23', 'CNOT 17 14', 'CNOT 18 15', 'BARRIER', 'CNOT 6 9', 'CNOT 24 26', 'CNOT 1 3', 'CNOT 16 20', 'CNOT 7 10', 'CNOT 17 21', 'CNOT 8 11', 'BARRIER', 'H 6', 'H 24', 'H 1', 'H 16', 'H 7', 'H 25', 'H 17', 'H 8', 'H 18', 'M 6', 'M 24', 'M 1', 'M 16', 'M 7', 'M 25', 'M 17', 'M 8', 'M 18', 'H 6', 'H 24', 'H 1', 'H 16', 'H 7', 'H 25', 'H 17', 'H 8', 'H 18', 'R 6', 'R 24', 'R 1', 'R 16', 'R 7', 'R 25', 'R 17', 'R 8', 'R 18', 'CNOT 0 1', 'CNOT 12 16', 'CNOT 4 7', 'CNOT 22 25', 'CNOT 13 17', 'CNOT 5 8', 'CNOT 14 18', 'BARRIER', 'CNOT 2 1', 'CNOT 19 16', 'CNOT 9 7', 'CNOT 26 25', 'CNOT 20 17', 'CNOT 10 8', 'CNOT 21 18', 'BARRIER', 'CNOT 2 6', 'CNOT 19 24', 'CNOT 9 16', 'CNOT 3 7', 'CNOT 20 25', 'CNOT 10 17', 'CNOT 11 18', 'BARRIER', 'CNOT  ...
# [0, 2, 3, 4, 5, 9, 10, 11, 12, 13, 14, 15, 19, 20, 21, 22, 23, 26, 27]
# [<src.utils.qccd_nodes.QubitIon object at 0x000001E06DF528D0>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E2EB750>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E2E8950>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E2EBC90>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E83F710>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E83ED90>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E83D950>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06DAB51D0>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06DAB4B90>]
# [<src.utils.qccd_nodes.QubitIon object at 0x000001E06DF52A10>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06DF50C90>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06DF51650>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06DF52850>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06DF51ED0>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E2EB5D0>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E2E9950>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E2E8850>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E2E9010>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E2E9F90>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E83F150>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E83EC50>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E83D290>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E83EAD0>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06DAB4850>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06DAB5210>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06DAB5450>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06DAB7510>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06DAB4BD0>]
# {0: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06DF52A10>, (0.0, 0.0)), 1: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06DF528D0>, (1.0, 1.0)), 2: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06DF50C90>, (2.0, 0.0)), 3: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06DF51650>, (2.0, 2.0)), 4: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06DF52850>, (3.0, 1.0)), 5: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06DF51ED0>, (3.0, 3.0)), 6: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E2EB750>, (4.0, 0.0)), 7: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E2E8950>, (4.0, 2.0)), 8: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E2EBC90>, (4.0, 4.0)), 9: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E2EB5D0>, (5.0, 1.0)), 10: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E2E9950>, (5.0, 3.0)), 11: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E2E8850>, (5.0, 5.0)), 12: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E2E9010>, (6.0, 0.0)), 13: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E2E9F90>, (6.0, 2.0)), 14: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E83F150>, (6.0, 4.0)), 15: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E83EC50>, (6.0, 6.0)), 16: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E83F710>, (7.0, 1.0)), 17: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E83ED90>, (7.0, 3.0)), 18: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E83D950>, (7.0, 5.0)), 19: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E83D290>, (8.0, 0.0)), 20: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E83EAD0>, (8.0, 2.0)), 21: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06DAB4850>, (8.0, 4.0)), 22: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06DAB5210>, (9.0, 1.0)), 23: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06DAB5450>, (9.0, 3.0)), 24: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06DAB51D0>, (10.0, 0.0)), 25: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06DAB4B90>, (10.0, 2.0)), 26: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06DAB7510>, (11.0, 1.0)), 27: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06DAB4BD0>, (12.0, 0.0))}

# %%
qccd = QCCDCircuit.generated(
        "surface_code:rotated_memory_z",
        rounds=2,
        distance=3,)
print(f'before circuitString: {qccd}')
print(f'after circuitString: {qccd.circuitString()}')
qccd._parseCircuitString()
print(qccd._measurementIons)
print(qccd._dataIons)
print(qccd._ionMapping)
# Out:
# before circuitString: QUBIT_COORDS(1, 1) 1
# QUBIT_COORDS(2, 0) 2
# QUBIT_COORDS(3, 1) 3
# QUBIT_COORDS(5, 1) 5
# QUBIT_COORDS(1, 3) 8
# QUBIT_COORDS(2, 2) 9
# QUBIT_COORDS(3, 3) 10
# QUBIT_COORDS(4, 2) 11
# QUBIT_COORDS(5, 3) 12
# QUBIT_COORDS(6, 2) 13
# QUBIT_COORDS(0, 4) 14
# QUBIT_COORDS(1, 5) 15
# QUBIT_COORDS(2, 4) 16
# QUBIT_COORDS(3, 5) 17
# QUBIT_COORDS(4, 4) 18
# QUBIT_COORDS(5, 5) 19
# QUBIT_COORDS(4, 6) 25
# R 1 3 5 8 10 12 15 17 19 2 9 11 13 14 16 18 25
# TICK
# H 2 11 16 25
# TICK
# CX 2 3 16 17 11 12 15 14 10 9 19 18
# TICK
# CX 2 1 16 15 11 10 8 14 3 9 12 18
# TICK
# CX 16 10 11 5 25 19 8 9 17 18 12 13
# TICK
# CX 16 8 11 3 25 17 1 9 10 18 5 13
# TICK
# H 2 11 16 25
# TICK
# MR 2 9 11 13 14 16 18 25
# DETECTOR(0, 4, 0) rec[-4]
# DETECTOR(2, 2, 0) rec[-7]
# DETECTOR(4, 4, 0) rec[-2]
# DETECTOR(6, 2, 0) rec[-5]
# TICK
# H 2 11 16 25
# TICK
# CX 2 3 16 17 11 12 15 14 10 9 19 18
# TICK
# CX 2 1 16 15 11 10 8 14 3 9 12 18
# TICK
# CX 16 10 11 5 25 19 8 9 17 18 12 13
# TICK
# CX 16 8 11 3 25 17 1 9 10 18 5 13
# TICK
# H 2 11 16 25
# TICK
# MR 2 9 11 13 14 16 18 25
# SHIFT_COORDS(0, 0, 1)
# DETECTOR(2, 0, 0) rec[-8] rec[-16]
# DETECTOR(2, 2, 0) rec[-7] rec[-15]
# DETECTOR(4, 2, 0) rec[-6] rec[-14]
# DETECTOR(6, 2, 0) rec[-5] rec[-13]
# DETECTOR(0, 4, 0) rec[-4] rec[-12]
# DETECTOR(2, 4, 0) rec[-3] rec[-11]
# DETECTOR(4, 4, 0) rec[-2] rec[-10]
# DETECTOR(4, 6, 0) rec[-1] rec[-9]
# M 1 3 5 8 10 12 15 17 19
# DETECTOR(0, 4, 1) rec[-3] rec[-6] rec[-13]
# DETECTOR(2, 2, 1) rec[-5] rec[-6] rec[-8] rec[-9] rec[-16]
# DETECTOR(4, 4, 1) rec[-1] rec[-2] rec[-4] rec[-5] rec[-11]
# DETECTOR(6, 2, 1) rec[-4] rec[-7] rec[-14]
# OBSERVABLE_INCLUDE(0) rec[-7] rec[-8] rec[-9]
# after circuitString: ['QUBIT_COORDS(1, 1) 1', 'QUBIT_COORDS(2, 0) 2', 'QUBIT_COORDS(3, 1) 3', 'QUBIT_COORDS(5, 1) 5', 'QUBIT_COORDS(1, 3) 8', 'QUBIT_COORDS(2, 2) 9', 'QUBIT_COORDS(3, 3) 10', 'QUBIT_COORDS(4, 2) 11', 'QUBIT_COORDS(5, 3) 12', 'QUBIT_COORDS(6, 2) 13', 'QUBIT_COORDS(0, 4) 14', 'QUBIT_COORDS(1, 5) 15', 'QUBIT_COORDS(2, 4) 16', 'QUBIT_COORDS(3, 5) 17', 'QUBIT_COORDS(4, 4) 18', 'QUBIT_COORDS(5, 5) 19', 'QUBIT_COORDS(4, 6) 25', 'R 1', 'R 3', 'R 5', 'R 8', 'R 10', 'R 12', 'R 15', 'R 17', 'R 19', 'R 2', 'R 9', 'R 11', 'R 13', 'R 14', 'R 16', 'R 18', 'R 25', 'H 2', 'H 11', 'H 16', 'H 25', 'CNOT 2 3', 'CNOT 16 17', 'CNOT 11 12', 'CNOT 15 14', 'CNOT 10 9', 'CNOT 19 18', 'BARRIER', 'CNOT 2 1', 'CNOT 16 15', 'CNOT 11 10', 'CNOT 8 14', 'CNOT 3 9', 'CNOT 12 18', 'BARRIER', 'CNOT 16 10', 'CNOT 11 5', 'CNOT 25 19', 'CNOT 8 9', 'CNOT 17 18', 'CNOT 12 13', 'BARRIER', 'CNOT 16 8', 'CNOT 11 3', 'CNOT 25 17', 'CNOT 1 9', 'CNOT 10 18', 'CNOT 5 13', 'BARRIER', 'H 2', 'H 11', 'H 16', 'H 25', 'M 2', 'M 9', 'M 11', 'M 13', 'M 14', 'M 16', 'M 18', 'M 25', 'R 2', 'R 9', 'R 11', 'R 13', 'R 14', 'R 16', 'R 18', 'R 25', 'H 2', 'H 11', 'H 16', 'H 25', 'CNOT 2 3', 'CNOT 16 17', 'CNOT 11 12', 'CNOT 15 14', 'CNOT 10 9', 'CNOT 19 18', 'BARRIER', 'CNOT 2 1', 'CNOT 16 15', 'CNOT 11 10', 'CNOT 8 14', 'CNOT 3 9', 'CNOT 12 18', 'BARRIER', 'CNOT 16 10', 'CNOT 11 5', 'CNOT 25 19', 'CNOT 8 9', 'CNOT 17 18', 'CNOT 12 13', 'BARRIER', 'CNOT 16 8', 'CNOT 11 3', 'CNOT 25 17', 'CNOT 1 9', 'CNOT 10 18', 'CNOT 5 13', 'BARRIER', 'H 2', 'H 11', 'H 16', 'H 25', 'M 2', 'M 9', 'M 11', 'M 13', 'M 14', 'M 16', 'M 18', 'M 25', 'R 2', 'R 9', 'R 11', 'R 13', 'R 14', 'R 16', 'R 18', 'R 25', 'M 1', 'M 3', 'M 5', 'M 8', 'M 10', 'M 12', 'M 15', 'M 17', 'M 19']
# [<src.utils.qccd_nodes.QubitIon object at 0x00000272A42E6A50>, <src.utils.qccd_nodes.QubitIon object at 0x00000272AD0D3650>, <src.utils.qccd_nodes.QubitIon object at 0x00000272AD0D0250>, <src.utils.qccd_nodes.QubitIon object at 0x00000272A45475D0>, <src.utils.qccd_nodes.QubitIon object at 0x00000272AD22D510>, <src.utils.qccd_nodes.QubitIon object at 0x00000272AD22C450>, <src.utils.qccd_nodes.QubitIon object at 0x00000272AD22F110>, <src.utils.qccd_nodes.QubitIon object at 0x00000272AD22C8D0>]
# [<src.utils.qccd_nodes.QubitIon object at 0x00000272ABDFB690>, <src.utils.qccd_nodes.QubitIon object at 0x00000272AD0D0BD0>, <src.utils.qccd_nodes.QubitIon object at 0x00000272AD0D04D0>, <src.utils.qccd_nodes.QubitIon object at 0x00000272AD0D00D0>, <src.utils.qccd_nodes.QubitIon object at 0x00000272AD0D2D50>, <src.utils.qccd_nodes.QubitIon object at 0x00000272A4545190>, <src.utils.qccd_nodes.QubitIon object at 0x00000272AD22C710>, <src.utils.qccd_nodes.QubitIon object at 0x00000272AD22D150>, <src.utils.qccd_nodes.QubitIon object at 0x00000272AD22D7D0>]
# {1: (<src.utils.qccd_nodes.QubitIon object at 0x00000272ABDFB690>, (1.0, 1.0)), 2: (<src.utils.qccd_nodes.QubitIon object at 0x00000272A42E6A50>, (2.0, 0.0)), 3: (<src.utils.qccd_nodes.QubitIon object at 0x00000272AD0D0BD0>, (3.0, 1.0)), 5: (<src.utils.qccd_nodes.QubitIon object at 0x00000272AD0D04D0>, (5.0, 1.0)), 8: (<src.utils.qccd_nodes.QubitIon object at 0x00000272AD0D00D0>, (1.0, 3.0)), 9: (<src.utils.qccd_nodes.QubitIon object at 0x00000272AD0D3650>, (2.0, 2.0)), 10: (<src.utils.qccd_nodes.QubitIon object at 0x00000272AD0D2D50>, (3.0, 3.0)), 11: (<src.utils.qccd_nodes.QubitIon object at 0x00000272AD0D0250>, (4.0, 2.0)), 12: (<src.utils.qccd_nodes.QubitIon object at 0x00000272A4545190>, (5.0, 3.0)), 13: (<src.utils.qccd_nodes.QubitIon object at 0x00000272A45475D0>, (6.0, 2.0)), 14: (<src.utils.qccd_nodes.QubitIon object at 0x00000272AD22D510>, (0.0, 4.0)), 15: (<src.utils.qccd_nodes.QubitIon object at 0x00000272AD22C710>, (1.0, 5.0)), 16: (<src.utils.qccd_nodes.QubitIon object at 0x00000272AD22C450>, (2.0, 4.0)), 17: (<src.utils.qccd_nodes.QubitIon object at 0x00000272AD22D150>, (3.0, 5.0)), 18: (<src.utils.qccd_nodes.QubitIon object at 0x00000272AD22F110>, (4.0, 4.0)), 19: (<src.utils.qccd_nodes.QubitIon object at 0x00000272AD22D7D0>, (5.0, 5.0)), 25: (<src.utils.qccd_nodes.QubitIon object at 0x00000272AD22C8D0>, (4.0, 6.0))}

# %%
from color_code_stim import ColorCode

colorcode = ColorCode(d=5,rounds=2,circuit_type="tri")
print(str(colorcode.circuit))
qccd = QCCDCircuit(str(colorcode.circuit))
print(f'before circuitString: {qccd.flattened().decomposed()}')
print(f'after circuitString: {qccd.circuitString()}')
qccd._parseCircuitString()
#print(f"parsed: {qccd._parseCircuitString()}")
print(qccd._measurementIons)
print(qccd._dataIons)
print(qccd._ionMapping)
# Out:
# QUBIT_COORDS(0, 0) 0
# QUBIT_COORDS(4, 0) 1
# QUBIT_COORDS(7, 0) 2
# QUBIT_COORDS(9, 0) 3
# QUBIT_COORDS(12, 0) 4
# QUBIT_COORDS(1, 1) 5
# QUBIT_COORDS(3, 1) 6
# QUBIT_COORDS(6, 1) 7
# QUBIT_COORDS(10, 1) 8
# QUBIT_COORDS(4, 2) 9
# QUBIT_COORDS(7, 2) 10
# QUBIT_COORDS(9, 2) 11
# QUBIT_COORDS(6, 3) 12
# R 0 1 4 7 8 9 12 2 5 10
# RX 3 6 11
# TICK
# CX 1 2 9 10
# TICK
# CX 7 2 12 10 3 1 11 9
# TICK
# CX 8 2 9 5 3 7 11 12
# TICK
# CX 0 5 7 10 3 8 6 9
# TICK
# CX 1 5 8 10 6 0 11 7
# TICK
# CX 4 2 7 5 6 1 11 8
# TICK
# CX 3 4 6 7
# TICK
# MR(0) 2 5 10
# MRX(0) 3 6 11
# DETECTOR(7, 0, 0, 2, 1) rec[-6]
# DETECTOR(1, 1, 0, 2, 2) rec[-5]
# DETECTOR(7, 2, 0, 2, 0) rec[-4]
# TICK
# SHIFT_COORDS(0, 0, 1)
# CX 1 2 9 10
# TICK
# CX 7 2 12 10 3 1 11 9
# TICK
# CX 8 2 9 5 3 7 11 12
# TICK
# CX 0 5 7 10 3 8 6 9
# TICK
# CX 1 5 8 10 6 0 11 7
# TICK
# CX 4 2 7 5 6 1 11 8
# TICK
# CX 3 4 6 7
# TICK
# MR(0) 2 5 10
# MRX(0) 3 6 11
# DETECTOR(7, 0, 0, 2, 1) rec[-6] rec[-12]
# DETECTOR(1, 1, 0, 2, 2) rec[-5] rec[-11]
# DETECTOR(7, 2, 0, 2, 0) rec[-4] rec[-10]
# DETECTOR(9, 0, 0, 0, 1) rec[-3] rec[-9]
# DETECTOR(3, 1, 0, 0, 2) rec[-2] rec[-8]
# DETECTOR(9, 2, 0, 0, 0) rec[-1] rec[-7]
# TICK
# SHIFT_COORDS(0, 0, 1)
# M(0) 0 1 4 7 8 9 12
# DETECTOR(7, 0, 0, 2, 1) rec[-6] rec[-5] rec[-4] rec[-3] rec[-13]
# DETECTOR(1, 1, 0, 2, 2) rec[-7] rec[-6] rec[-4] rec[-2] rec[-12]
# DETECTOR(7, 2, 0, 2, 0) rec[-4] rec[-3] rec[-2] rec[-1] rec[-11]
# OBSERVABLE_INCLUDE(0) rec[-7] rec[-6] rec[-5]
# before circuitString: QUBIT_COORDS(0, 0) 0
# QUBIT_COORDS(4, 0) 1
# QUBIT_COORDS(7, 0) 2
# QUBIT_COORDS(9, 0) 3
# QUBIT_COORDS(12, 0) 4
# QUBIT_COORDS(1, 1) 5
# QUBIT_COORDS(3, 1) 6
# QUBIT_COORDS(6, 1) 7
# QUBIT_COORDS(10, 1) 8
# QUBIT_COORDS(4, 2) 9
# QUBIT_COORDS(7, 2) 10
# QUBIT_COORDS(9, 2) 11
# QUBIT_COORDS(6, 3) 12
# R 0 1 4 7 8 9 12 2 5 10 3 6 11
# H 3 6 11
# TICK
# CX 1 2 9 10
# TICK
# CX 7 2 12 10 3 1 11 9
# TICK
# CX 8 2 9 5 3 7 11 12
# TICK
# CX 0 5 7 10 3 8 6 9
# TICK
# CX 1 5 8 10 6 0 11 7
# TICK
# CX 4 2 7 5 6 1 11 8
# TICK
# CX 3 4 6 7
# TICK
# M 2 5 10
# R 2 5 10
# H 3 6 11
# M 3 6 11
# R 3 6 11
# H 3 6 11
# DETECTOR(7, 0, 0, 2, 1) rec[-6]
# DETECTOR(1, 1, 0, 2, 2) rec[-5]
# DETECTOR(7, 2, 0, 2, 0) rec[-4]
# TICK
# CX 1 2 9 10
# TICK
# CX 7 2 12 10 3 1 11 9
# TICK
# CX 8 2 9 5 3 7 11 12
# TICK
# CX 0 5 7 10 3 8 6 9
# TICK
# CX 1 5 8 10 6 0 11 7
# TICK
# CX 4 2 7 5 6 1 11 8
# TICK
# CX 3 4 6 7
# TICK
# M 2 5 10
# R 2 5 10
# H 3 6 11
# M 3 6 11
# R 3 6 11
# H 3 6 11
# DETECTOR(7, 0, 1, 2, 1) rec[-6] rec[-12]
# DETECTOR(1, 1, 1, 2, 2) rec[-5] rec[-11]
# DETECTOR(7, 2, 1, 2, 0) rec[-4] rec[-10]
# DETECTOR(9, 0, 1, 0, 1) rec[-3] rec[-9]
# DETECTOR(3, 1, 1, 0, 2) rec[-2] rec[-8]
# DETECTOR(9, 2, 1, 0, 0) rec[-1] rec[-7]
# TICK
# M 0 1 4 7 8 9 12
# DETECTOR(7, 0, 2, 2, 1) rec[-6] rec[-5] rec[-4] rec[-3] rec[-13]
# DETECTOR(1, 1, 2, 2, 2) rec[-7] rec[-6] rec[-4] rec[-2] rec[-12]
# DETECTOR(7, 2, 2, 2, 0) rec[-4] rec[-3] rec[-2] rec[-1] rec[-11]
# OBSERVABLE_INCLUDE(0) rec[-7] rec[-6] rec[-5]
# after circuitString: ['QUBIT_COORDS(0, 0) 0', 'QUBIT_COORDS(4, 0) 1', 'QUBIT_COORDS(7, 0) 2', 'QUBIT_COORDS(9, 0) 3', 'QUBIT_COORDS(12, 0) 4', 'QUBIT_COORDS(1, 1) 5', 'QUBIT_COORDS(3, 1) 6', 'QUBIT_COORDS(6, 1) 7', 'QUBIT_COORDS(10, 1) 8', 'QUBIT_COORDS(4, 2) 9', 'QUBIT_COORDS(7, 2) 10', 'QUBIT_COORDS(9, 2) 11', 'QUBIT_COORDS(6, 3) 12', 'R 0', 'R 1', 'R 4', 'R 7', 'R 8', 'R 9', 'R 12', 'R 2', 'R 5', 'R 10', 'R 3', 'R 6', 'R 11', 'H 3', 'H 6', 'H 11', 'CNOT 1 2', 'CNOT 9 10', 'BARRIER', 'CNOT 7 2', 'CNOT 12 10', 'CNOT 3 1', 'CNOT 11 9', 'BARRIER', 'CNOT 8 2', 'CNOT 9 5', 'CNOT 3 7', 'CNOT 11 12', 'BARRIER', 'CNOT 0 5', 'CNOT 7 10', 'CNOT 3 8', 'CNOT 6 9', 'BARRIER', 'CNOT 1 5', 'CNOT 8 10', 'CNOT 6 0', 'CNOT 11 7', 'BARRIER', 'CNOT 4 2', 'CNOT 7 5', 'CNOT 6 1', 'CNOT 11 8', 'BARRIER', 'CNOT 3 4', 'CNOT 6 7', 'BARRIER', 'M 2', 'M 5', 'M 10', 'R 2', 'R 5', 'R 10', 'H 3', 'H 6', 'H 11', 'M 3', 'M 6', 'M 11', 'R 3', 'R 6', 'R 11', 'H 3', 'H 6', 'H 11', 'CNOT 1 2', 'CNOT 9 10', 'BARRIER', 'CNOT 7 2', 'CNOT 12 10', 'CNOT 3 1', 'CNOT 11 9', 'BARRIER', 'CNOT 8 2', 'CNOT 9 5', 'CNOT 3 7', 'CNOT 11 12', 'BARRIER', 'CNOT 0 5', 'CNOT 7 10', 'CNOT 3 8', 'CNOT 6 9', 'BARRIER', 'CNOT 1 5', 'CNOT 8 10', 'CNOT 6 0', 'CNOT 11 7', 'BARRIER', 'CNOT 4 2', 'CNOT 7 5', 'CNOT 6 1', 'CNOT 11 8', 'BARRIER', 'CNOT 3 4', 'CNOT 6 7', 'BARRIER', 'M 2', 'M 5', 'M 10', 'R 2', 'R 5', 'R 10', 'H 3', 'H 6', 'H 11', 'M 3', 'M 6', 'M 11', 'R 3', 'R 6', 'R 11', 'H 3', 'H 6', 'H 11', 'M 0', 'M 1', 'M 4', 'M 7', 'M 8', 'M 9', 'M 12']
# parsed: ([<src.utils.qccd_operations_on_qubits.QubitReset object at 0x000001E06E83F150>, <src.utils.qccd_operations_on_qubits.QubitReset object at 0x000001E071464650>, <src.utils.qccd_operations_on_qubits.QubitReset object at 0x000001E06DAB5450>, <src.utils.qccd_operations_on_qubits.QubitReset object at 0x000001E06DAB4B90>, <src.utils.qccd_operations_on_qubits.QubitReset object at 0x000001E0714DB110>, <src.utils.qccd_operations_on_qubits.QubitReset object at 0x000001E0714DAE10>, <src.utils.qccd_operations_on_qubits.QubitReset object at 0x000001E0714DAF10>, <src.utils.qccd_operations_on_qubits.QubitReset object at 0x000001E0714DB150>, <src.utils.qccd_operations_on_qubits.QubitReset object at 0x000001E0714DB290>, <src.utils.qccd_operations_on_qubits.QubitReset object at 0x000001E0714DB350>, <src.utils.qccd_operations_on_qubits.QubitReset object at 0x000001E0714DB4D0>, <src.utils.qccd_operations_on_qubits.QubitReset object at 0x000001E0714DB610>, <src.utils.qccd_operations_on_qubits.QubitReset object at 0x000001E0714DB750>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714DB890>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714DB9D0>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714DBA90>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714DBBD0>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714DBD10>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714DBE50>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714DBF90>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714E4110>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714E4250>, <src.utils.qccd_operations_on_qubits.TwoQubitMSGate object at 0x000001E0714E4310>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714E4450>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714E4610>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714E46D0>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714E4810>, <src.utils.qccd_operations_on_qubits.TwoQubitMSGate object at 0x000001E0714E4950>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714E4A50>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714E4BD0>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714E4D10>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714E4E50>, <src.utils.qccd_operations_on_qubits.TwoQubitMSGate object at 0x000001E0714E4F90>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714E5090>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714E52D0>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714E5350>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714E5490>, <src.utils.qccd_operations_on_qubits.TwoQubitMSGate object at 0x000001E0714E55D0>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714E56D0>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714E5850>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714E5990>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714E5AD0>, <src.utils.qccd_operations_on_qubits.TwoQubitMSGate object at 0x000001E0714E5C10>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714E5D10>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714E5F10>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714E5FD0>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714E6110>, <src.utils.qccd_operations_on_qubits.TwoQubitMSGate object at 0x000001E0714E6250>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714E6350>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714E64D0>, <src.utils.qccd_operations_on_qubits.XRotation  ...
# [<src.utils.qccd_nodes.QubitIon object at 0x000001E07096DF10>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06DF51650>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E2EB5D0>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E2E8850>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E83EAD0>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E83ED90>]
# [<src.utils.qccd_nodes.QubitIon object at 0x000001E06F66B710>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E0E50D0>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06DF52A10>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E2E9F90>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E2E9950>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E2E8950>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E83EC50>]
# {0: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06F66B710>, (0.0, 0.0)), 1: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E0E50D0>, (4.0, 0.0)), 2: (<src.utils.qccd_nodes.QubitIon object at 0x000001E07096DF10>, (7.0, 0.0)), 3: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06DF51650>, (9.0, 0.0)), 4: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06DF52A10>, (12.0, 0.0)), 5: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E2EB5D0>, (1.0, 1.0)), 6: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E2E8850>, (3.0, 1.0)), 7: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E2E9F90>, (6.0, 1.0)), 8: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E2E9950>, (10.0, 1.0)), 9: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E2E8950>, (4.0, 2.0)), 10: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E83EAD0>, (7.0, 2.0)), 11: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E83ED90>, (9.0, 2.0)), 12: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E83EC50>, (6.0, 3.0))}

# %%
def process_circuit(distance, capacity, gate_improvements, num_shots):
    logger = get_logger()
    logger.setLevel(logging.INFO)
    handler = logging.FileHandler("process_log.txt")
    formatter = logging.Formatter('%(processName)s - %(levelname)s - %(message)s')
    handler.setFormatter(formatter)
    logger.addHandler(handler)

    logger.info(f"Starting circuit generation for distance {distance} and capacity {capacity}")

    colorcode = ColorCode(d=distance,rounds=2,circuit_type="tri")
    circuit = QCCDCircuit(str(colorcode.circuit))
    nqubitsNeeded = (9*distance**2 -1)//8

    nrowsNeeded = int(np.sqrt(nqubitsNeeded))+2

    logger.info(f"Processing circuit with {nqubitsNeeded} qubits and {nrowsNeeded} rows")

    arch, (instructions, _) = circuit.processCircuitAugmentedGrid(rows=nrowsNeeded, cols=nrowsNeeded, trapCapacity=capacity)
    # arch, (instructions, _) = circuit.processCircuitNetworkedGrid(traps=nqubitsNeeded, trapCapacity=capacity)
    arch.refreshGraph()

    results = {"ElapsedTime": {}, "Operations": {}, "MeanConcurrency": {}, "QubitOperations": {}, "LogicalErrorRates": {}, "PhysicalZErrorRates": {}, "PhysicalXErrorRates": {}, "Electrodes": {}, "DACs": {}}

    # FIXME legacy formatting!
    label ="Forwarding"

    logger.info(f"Processing operations using {label} for distance {distance} and capacity {capacity}")
    allOps, barriers = ionRouting(arch, instructions, capacity)
 
    parallelOpsMap = paralleliseOperationsWithBarriers(allOps, barriers)
    logicalErrors = []
    physicalZErrors = []
    physicalXErrors = []
    
    for gate_improvement in gate_improvements:
        logicalError, physicalXError, physicalZError = circuit.simulate(allOps, num_shots=num_shots, error_scaling=gate_improvement)
        logicalErrors.append(logicalError)
        physicalZErrors.append(physicalZError)
        physicalXErrors.append(physicalXError)

    logger.info(f"Simulated {label} method with gate improvements for distance {distance}, capacity {capacity}")
    
    
    for op in parallelOpsMap.values():
        op.calculateOperationTime()
        op.calculateFidelity()

    circuit.resetArch()
    arch.refreshGraph()

    results["Capacity"] = capacity
    results["Distance"] = distance
    results["ElapsedTime"][label] = max(parallelOpsMap.keys())
    results["Operations"][label] = len(allOps)
    results["MeanConcurrency"][label] = np.mean([len(op.operations) for op in parallelOpsMap.values()])
    results["QubitOperations"][label] = len(instructions)
    results["LogicalErrorRates"][label] = logicalErrors
    results["PhysicalZErrorRates"][label] = physicalZErrors
    results["PhysicalXErrorRates"][label] = physicalXErrors


    trapSet = set()
    junctionSet = set()
    for op in allOps:
        for c in op.involvedComponents:
            if isinstance(c, Trap):
                trapSet.add(c)
            elif isinstance(c, Junction):
                junctionSet.add(c)

    # Every zone can contain up to two qubits
    # Njz = 1*Nj, Nlz = Nl*k
    # The number of zones  N = 1*Nj+k*Nl
    Njz = len(junctionSet) # each junction is one zone
    Nlz = len(trapSet)*capacity # each trap is k zones

    # Njz = int(np.ceil(nqubitsNeeded / (2*(capacity-1))) )# 2 traps per junction
    # Nlz = nqubitsNeeded-Njz
    Nde = NDE_LZ*Nlz+NDE_JZ*Njz
    Nse = NSE_Z*(Njz+Nlz)

    Num_electrodes = Nde+Nse
    Num_DACs = Num_electrodes
    results["DACs"][label] = Num_DACs
    results["Electrodes"][label] = Num_electrodes

    logger.info(f"{distance} {capacity} {label} = {results}")
    
    logger.info(f"Finished processing for distance {distance} and capacity {capacity}")
    return results

process_circuit(5,2,[1.0],100_000)
