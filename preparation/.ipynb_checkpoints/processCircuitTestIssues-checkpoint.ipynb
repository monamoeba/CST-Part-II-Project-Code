# %%
import sys
import os
# Add the parent directory to the Python path
os.chdir('..')
print(os.getcwd())
# Out:
# C:\Users\monam\OneDrive\Desktop\UNI\II\PartIIProject\CST-Part-II-Project-Code

# %%
from src.simulator.qccd_circuit import process_circuit

ds = [3,5,7]

for d in ds: 
    print(process_circuit(d,2,[1.0],100_000)) 
    #print(process_circuit_wise_arch(d,c,[1.0], 100_000)) 
    print('\n')
# Out:
# {'ElapsedTime': {'Forwarding': 0.004085000000000001}, 'Operations': {'Forwarding': 466}, 'MeanConcurrency': {'Forwarding': np.float64(6.781818181818182)}, 'QubitOperations': {'Forwarding': 178}, 'LogicalErrorRates': {'Forwarding': [0.05481]}, 'PhysicalZErrorRates': {'Forwarding': [np.float64(0.006711326100063682)]}, 'PhysicalXErrorRates': {'Forwarding': [np.float64(0.006163226932548814)]}, 'Electrodes': {'Forwarding': 980}, 'DACs': {'Forwarding': 980}, 'Capacity': 2, 'Distance': 3}
#
#
# {'ElapsedTime': {'Forwarding': 0.004085000000000001}, 'Operations': {'Forwarding': 1530}, 'MeanConcurrency': {'Forwarding': np.float64(20.115151515151513)}, 'QubitOperations': {'Forwarding': 570}, 'LogicalErrorRates': {'Forwarding': [0.02013]}, 'PhysicalZErrorRates': {'Forwarding': [np.float64(0.007041585573227546)]}, 'PhysicalXErrorRates': {'Forwarding': [np.float64(0.006418054713602888)]}, 'Electrodes': {'Forwarding': 2800}, 'DACs': {'Forwarding': 2800}, 'Capacity': 2, 'Distance': 5}
#
#
# {'ElapsedTime': {'Forwarding': 0.004080000000000001}, 'Operations': {'Forwarding': 3194}, 'MeanConcurrency': {'Forwarding': np.float64(39.66257668711656)}, 'QubitOperations': {'Forwarding': 1178}, 'LogicalErrorRates': {'Forwarding': [0.01356]}, 'PhysicalZErrorRates': {'Forwarding': [np.float64(0.007176006624135872)]}, 'PhysicalXErrorRates': {'Forwarding': [np.float64(0.006528395848468784)]}, 'Electrodes': {'Forwarding': 5500}, 'DACs': {'Forwarding': 5500}, 'Capacity': 2, 'Distance': 7}

# %%
from src.simulator.qccd_circuit import *
from src.color_code_utils.color_code_circuits.color_code_circuit_666 import *

# testing the color code versions
ds = [3,5,7]

for d in ds:
    print(process_color_code_circuit(d,2,[1.0],100_000, (6,6,6)))
    print('\n')
    
"""
#ccobj = ColorCodeCircuit666(3,2)
qccd = QCCDCircuit.generate_color_code(5,2,(6,6,6))
print(f'before circuitString: {qccd}')
print(f'after circuitString: {qccd.circuitString()}')
#print(qccd.dataQubitsIdxs)
qccd._parseCircuitString(qccd.dataQubitsIdxs)
#print(qccd._measurementIons)
#print(qccd._dataIons)
#print(qccd._ionMapping)
#the measurement qubits aren't being picked up for some reason
"""
# Out:
# {'ElapsedTime': {'Forwarding': 0.04180999999999999}, 'Operations': {'Forwarding': 4259}, 'MeanConcurrency': {'Forwarding': np.float64(5.351455244371224)}, 'QubitOperations': {'Forwarding': 1067}, 'LogicalErrorRates': {'Forwarding': [0.41146]}, 'PhysicalZErrorRates': {'Forwarding': [np.float64(0.017107091516600906)]}, 'PhysicalXErrorRates': {'Forwarding': [np.float64(0.015584616040494255)]}, 'Electrodes': {'Forwarding': 1600}, 'DACs': {'Forwarding': 1600}, 'Capacity': 2, 'Distance': 5}
# "\n#ccobj = ColorCodeCircuit666(3,2)\nqccd = QCCDCircuit.generate_color_code(5,2,(6,6,6))\nprint(f'before circuitString: {qccd}')\nprint(f'after circuitString: {qccd.circuitString()}')\n#print(qccd.dataQubitsIdxs)\nqccd._parseCircuitString(qccd.dataQubitsIdxs)\n#print(qccd._measurementIons)\n#print(qccd._dataIons)\n#print(qccd._ionMapping)\n#the measurement qubits aren't being picked up for some reason\n"

# %%
qccd = QCCDCircuit.generated(
        "surface_code:rotated_memory_z",
        rounds=2,
        distance=3,)
print(f'before circuitString: {qccd}')
print(f'after circuitString: {qccd.circuitString()}')
qccd._parseCircuitString()
print(qccd._measurementIons)
print(qccd._dataIons)
print(qccd._ionMapping)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 qccd = QCCDCircuit.generated(
#       2         "surface_code:rotated_memory_z",
#       3         rounds=2,
#       4         distance=3,)
#       5 print(f'before circuitString: {qccd}')
#       6 print(f'after circuitString: {qccd.circuitString()}')
#
# NameError: name 'QCCDCircuit' is not defined

# %%
from color_code_stim import ColorCode

colorcode = ColorCode(d=5,rounds=2,circuit_type="tri")
print(str(colorcode.circuit))
qccd = QCCDCircuit(str(colorcode.circuit))
print(f'before circuitString: {qccd.flattened().decomposed()}')
print(f'after circuitString: {qccd.circuitString()}')
qccd._parseCircuitString()
#print(f"parsed: {qccd._parseCircuitString()}")
print(qccd._measurementIons)
print(qccd._dataIons)
print(qccd._ionMapping)
# Out:
# QUBIT_COORDS(0, 0) 0
# QUBIT_COORDS(4, 0) 1
# QUBIT_COORDS(7, 0) 2
# QUBIT_COORDS(9, 0) 3
# QUBIT_COORDS(12, 0) 4
# QUBIT_COORDS(1, 1) 5
# QUBIT_COORDS(3, 1) 6
# QUBIT_COORDS(6, 1) 7
# QUBIT_COORDS(10, 1) 8
# QUBIT_COORDS(4, 2) 9
# QUBIT_COORDS(7, 2) 10
# QUBIT_COORDS(9, 2) 11
# QUBIT_COORDS(6, 3) 12
# R 0 1 4 7 8 9 12 2 5 10
# RX 3 6 11
# TICK
# CX 1 2 9 10
# TICK
# CX 7 2 12 10 3 1 11 9
# TICK
# CX 8 2 9 5 3 7 11 12
# TICK
# CX 0 5 7 10 3 8 6 9
# TICK
# CX 1 5 8 10 6 0 11 7
# TICK
# CX 4 2 7 5 6 1 11 8
# TICK
# CX 3 4 6 7
# TICK
# MR(0) 2 5 10
# MRX(0) 3 6 11
# DETECTOR(7, 0, 0, 2, 1) rec[-6]
# DETECTOR(1, 1, 0, 2, 2) rec[-5]
# DETECTOR(7, 2, 0, 2, 0) rec[-4]
# TICK
# SHIFT_COORDS(0, 0, 1)
# CX 1 2 9 10
# TICK
# CX 7 2 12 10 3 1 11 9
# TICK
# CX 8 2 9 5 3 7 11 12
# TICK
# CX 0 5 7 10 3 8 6 9
# TICK
# CX 1 5 8 10 6 0 11 7
# TICK
# CX 4 2 7 5 6 1 11 8
# TICK
# CX 3 4 6 7
# TICK
# MR(0) 2 5 10
# MRX(0) 3 6 11
# DETECTOR(7, 0, 0, 2, 1) rec[-6] rec[-12]
# DETECTOR(1, 1, 0, 2, 2) rec[-5] rec[-11]
# DETECTOR(7, 2, 0, 2, 0) rec[-4] rec[-10]
# DETECTOR(9, 0, 0, 0, 1) rec[-3] rec[-9]
# DETECTOR(3, 1, 0, 0, 2) rec[-2] rec[-8]
# DETECTOR(9, 2, 0, 0, 0) rec[-1] rec[-7]
# TICK
# SHIFT_COORDS(0, 0, 1)
# M(0) 0 1 4 7 8 9 12
# DETECTOR(7, 0, 0, 2, 1) rec[-6] rec[-5] rec[-4] rec[-3] rec[-13]
# DETECTOR(1, 1, 0, 2, 2) rec[-7] rec[-6] rec[-4] rec[-2] rec[-12]
# DETECTOR(7, 2, 0, 2, 0) rec[-4] rec[-3] rec[-2] rec[-1] rec[-11]
# OBSERVABLE_INCLUDE(0) rec[-7] rec[-6] rec[-5]
# before circuitString: QUBIT_COORDS(0, 0) 0
# QUBIT_COORDS(4, 0) 1
# QUBIT_COORDS(7, 0) 2
# QUBIT_COORDS(9, 0) 3
# QUBIT_COORDS(12, 0) 4
# QUBIT_COORDS(1, 1) 5
# QUBIT_COORDS(3, 1) 6
# QUBIT_COORDS(6, 1) 7
# QUBIT_COORDS(10, 1) 8
# QUBIT_COORDS(4, 2) 9
# QUBIT_COORDS(7, 2) 10
# QUBIT_COORDS(9, 2) 11
# QUBIT_COORDS(6, 3) 12
# R 0 1 4 7 8 9 12 2 5 10 3 6 11
# H 3 6 11
# TICK
# CX 1 2 9 10
# TICK
# CX 7 2 12 10 3 1 11 9
# TICK
# CX 8 2 9 5 3 7 11 12
# TICK
# CX 0 5 7 10 3 8 6 9
# TICK
# CX 1 5 8 10 6 0 11 7
# TICK
# CX 4 2 7 5 6 1 11 8
# TICK
# CX 3 4 6 7
# TICK
# M 2 5 10
# R 2 5 10
# H 3 6 11
# M 3 6 11
# R 3 6 11
# H 3 6 11
# DETECTOR(7, 0, 0, 2, 1) rec[-6]
# DETECTOR(1, 1, 0, 2, 2) rec[-5]
# DETECTOR(7, 2, 0, 2, 0) rec[-4]
# TICK
# CX 1 2 9 10
# TICK
# CX 7 2 12 10 3 1 11 9
# TICK
# CX 8 2 9 5 3 7 11 12
# TICK
# CX 0 5 7 10 3 8 6 9
# TICK
# CX 1 5 8 10 6 0 11 7
# TICK
# CX 4 2 7 5 6 1 11 8
# TICK
# CX 3 4 6 7
# TICK
# M 2 5 10
# R 2 5 10
# H 3 6 11
# M 3 6 11
# R 3 6 11
# H 3 6 11
# DETECTOR(7, 0, 1, 2, 1) rec[-6] rec[-12]
# DETECTOR(1, 1, 1, 2, 2) rec[-5] rec[-11]
# DETECTOR(7, 2, 1, 2, 0) rec[-4] rec[-10]
# DETECTOR(9, 0, 1, 0, 1) rec[-3] rec[-9]
# DETECTOR(3, 1, 1, 0, 2) rec[-2] rec[-8]
# DETECTOR(9, 2, 1, 0, 0) rec[-1] rec[-7]
# TICK
# M 0 1 4 7 8 9 12
# DETECTOR(7, 0, 2, 2, 1) rec[-6] rec[-5] rec[-4] rec[-3] rec[-13]
# DETECTOR(1, 1, 2, 2, 2) rec[-7] rec[-6] rec[-4] rec[-2] rec[-12]
# DETECTOR(7, 2, 2, 2, 0) rec[-4] rec[-3] rec[-2] rec[-1] rec[-11]
# OBSERVABLE_INCLUDE(0) rec[-7] rec[-6] rec[-5]
# after circuitString: ['QUBIT_COORDS(0, 0) 0', 'QUBIT_COORDS(4, 0) 1', 'QUBIT_COORDS(7, 0) 2', 'QUBIT_COORDS(9, 0) 3', 'QUBIT_COORDS(12, 0) 4', 'QUBIT_COORDS(1, 1) 5', 'QUBIT_COORDS(3, 1) 6', 'QUBIT_COORDS(6, 1) 7', 'QUBIT_COORDS(10, 1) 8', 'QUBIT_COORDS(4, 2) 9', 'QUBIT_COORDS(7, 2) 10', 'QUBIT_COORDS(9, 2) 11', 'QUBIT_COORDS(6, 3) 12', 'R 0', 'R 1', 'R 4', 'R 7', 'R 8', 'R 9', 'R 12', 'R 2', 'R 5', 'R 10', 'R 3', 'R 6', 'R 11', 'H 3', 'H 6', 'H 11', 'CNOT 1 2', 'CNOT 9 10', 'BARRIER', 'CNOT 7 2', 'CNOT 12 10', 'CNOT 3 1', 'CNOT 11 9', 'BARRIER', 'CNOT 8 2', 'CNOT 9 5', 'CNOT 3 7', 'CNOT 11 12', 'BARRIER', 'CNOT 0 5', 'CNOT 7 10', 'CNOT 3 8', 'CNOT 6 9', 'BARRIER', 'CNOT 1 5', 'CNOT 8 10', 'CNOT 6 0', 'CNOT 11 7', 'BARRIER', 'CNOT 4 2', 'CNOT 7 5', 'CNOT 6 1', 'CNOT 11 8', 'BARRIER', 'CNOT 3 4', 'CNOT 6 7', 'BARRIER', 'M 2', 'M 5', 'M 10', 'R 2', 'R 5', 'R 10', 'H 3', 'H 6', 'H 11', 'M 3', 'M 6', 'M 11', 'R 3', 'R 6', 'R 11', 'H 3', 'H 6', 'H 11', 'CNOT 1 2', 'CNOT 9 10', 'BARRIER', 'CNOT 7 2', 'CNOT 12 10', 'CNOT 3 1', 'CNOT 11 9', 'BARRIER', 'CNOT 8 2', 'CNOT 9 5', 'CNOT 3 7', 'CNOT 11 12', 'BARRIER', 'CNOT 0 5', 'CNOT 7 10', 'CNOT 3 8', 'CNOT 6 9', 'BARRIER', 'CNOT 1 5', 'CNOT 8 10', 'CNOT 6 0', 'CNOT 11 7', 'BARRIER', 'CNOT 4 2', 'CNOT 7 5', 'CNOT 6 1', 'CNOT 11 8', 'BARRIER', 'CNOT 3 4', 'CNOT 6 7', 'BARRIER', 'M 2', 'M 5', 'M 10', 'R 2', 'R 5', 'R 10', 'H 3', 'H 6', 'H 11', 'M 3', 'M 6', 'M 11', 'R 3', 'R 6', 'R 11', 'H 3', 'H 6', 'H 11', 'M 0', 'M 1', 'M 4', 'M 7', 'M 8', 'M 9', 'M 12']
# parsed: ([<src.utils.qccd_operations_on_qubits.QubitReset object at 0x000001E06E83F150>, <src.utils.qccd_operations_on_qubits.QubitReset object at 0x000001E071464650>, <src.utils.qccd_operations_on_qubits.QubitReset object at 0x000001E06DAB5450>, <src.utils.qccd_operations_on_qubits.QubitReset object at 0x000001E06DAB4B90>, <src.utils.qccd_operations_on_qubits.QubitReset object at 0x000001E0714DB110>, <src.utils.qccd_operations_on_qubits.QubitReset object at 0x000001E0714DAE10>, <src.utils.qccd_operations_on_qubits.QubitReset object at 0x000001E0714DAF10>, <src.utils.qccd_operations_on_qubits.QubitReset object at 0x000001E0714DB150>, <src.utils.qccd_operations_on_qubits.QubitReset object at 0x000001E0714DB290>, <src.utils.qccd_operations_on_qubits.QubitReset object at 0x000001E0714DB350>, <src.utils.qccd_operations_on_qubits.QubitReset object at 0x000001E0714DB4D0>, <src.utils.qccd_operations_on_qubits.QubitReset object at 0x000001E0714DB610>, <src.utils.qccd_operations_on_qubits.QubitReset object at 0x000001E0714DB750>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714DB890>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714DB9D0>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714DBA90>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714DBBD0>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714DBD10>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714DBE50>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714DBF90>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714E4110>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714E4250>, <src.utils.qccd_operations_on_qubits.TwoQubitMSGate object at 0x000001E0714E4310>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714E4450>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714E4610>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714E46D0>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714E4810>, <src.utils.qccd_operations_on_qubits.TwoQubitMSGate object at 0x000001E0714E4950>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714E4A50>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714E4BD0>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714E4D10>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714E4E50>, <src.utils.qccd_operations_on_qubits.TwoQubitMSGate object at 0x000001E0714E4F90>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714E5090>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714E52D0>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714E5350>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714E5490>, <src.utils.qccd_operations_on_qubits.TwoQubitMSGate object at 0x000001E0714E55D0>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714E56D0>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714E5850>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714E5990>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714E5AD0>, <src.utils.qccd_operations_on_qubits.TwoQubitMSGate object at 0x000001E0714E5C10>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714E5D10>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714E5F10>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714E5FD0>, <src.utils.qccd_operations_on_qubits.XRotation object at 0x000001E0714E6110>, <src.utils.qccd_operations_on_qubits.TwoQubitMSGate object at 0x000001E0714E6250>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714E6350>, <src.utils.qccd_operations_on_qubits.YRotation object at 0x000001E0714E64D0>, <src.utils.qccd_operations_on_qubits.XRotation  ...
# [<src.utils.qccd_nodes.QubitIon object at 0x000001E07096DF10>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06DF51650>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E2EB5D0>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E2E8850>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E83EAD0>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E83ED90>]
# [<src.utils.qccd_nodes.QubitIon object at 0x000001E06F66B710>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E0E50D0>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06DF52A10>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E2E9F90>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E2E9950>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E2E8950>, <src.utils.qccd_nodes.QubitIon object at 0x000001E06E83EC50>]
# {0: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06F66B710>, (0.0, 0.0)), 1: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E0E50D0>, (4.0, 0.0)), 2: (<src.utils.qccd_nodes.QubitIon object at 0x000001E07096DF10>, (7.0, 0.0)), 3: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06DF51650>, (9.0, 0.0)), 4: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06DF52A10>, (12.0, 0.0)), 5: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E2EB5D0>, (1.0, 1.0)), 6: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E2E8850>, (3.0, 1.0)), 7: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E2E9F90>, (6.0, 1.0)), 8: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E2E9950>, (10.0, 1.0)), 9: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E2E8950>, (4.0, 2.0)), 10: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E83EAD0>, (7.0, 2.0)), 11: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E83ED90>, (9.0, 2.0)), 12: (<src.utils.qccd_nodes.QubitIon object at 0x000001E06E83EC50>, (6.0, 3.0))}

# %%
def process_circuit(distance, capacity, gate_improvements, num_shots):
    logger = get_logger()
    logger.setLevel(logging.INFO)
    handler = logging.FileHandler("process_log.txt")
    formatter = logging.Formatter('%(processName)s - %(levelname)s - %(message)s')
    handler.setFormatter(formatter)
    logger.addHandler(handler)

    logger.info(f"Starting circuit generation for distance {distance} and capacity {capacity}")

    colorcode = ColorCode(d=distance,rounds=2,circuit_type="tri")
    circuit = QCCDCircuit(str(colorcode.circuit))
    nqubitsNeeded = (9*distance**2 -1)//8

    nrowsNeeded = int(np.sqrt(nqubitsNeeded))+2

    logger.info(f"Processing circuit with {nqubitsNeeded} qubits and {nrowsNeeded} rows")

    arch, (instructions, _) = circuit.processCircuitAugmentedGrid(rows=nrowsNeeded, cols=nrowsNeeded, trapCapacity=capacity)
    # arch, (instructions, _) = circuit.processCircuitNetworkedGrid(traps=nqubitsNeeded, trapCapacity=capacity)
    arch.refreshGraph()

    results = {"ElapsedTime": {}, "Operations": {}, "MeanConcurrency": {}, "QubitOperations": {}, "LogicalErrorRates": {}, "PhysicalZErrorRates": {}, "PhysicalXErrorRates": {}, "Electrodes": {}, "DACs": {}}

    # FIXME legacy formatting!
    label ="Forwarding"

    logger.info(f"Processing operations using {label} for distance {distance} and capacity {capacity}")
    allOps, barriers = ionRouting(arch, instructions, capacity)
 
    parallelOpsMap = paralleliseOperationsWithBarriers(allOps, barriers)
    logicalErrors = []
    physicalZErrors = []
    physicalXErrors = []
    
    for gate_improvement in gate_improvements:
        logicalError, physicalXError, physicalZError = circuit.simulate(allOps, num_shots=num_shots, error_scaling=gate_improvement)
        logicalErrors.append(logicalError)
        physicalZErrors.append(physicalZError)
        physicalXErrors.append(physicalXError)

    logger.info(f"Simulated {label} method with gate improvements for distance {distance}, capacity {capacity}")
    
    
    for op in parallelOpsMap.values():
        op.calculateOperationTime()
        op.calculateFidelity()

    circuit.resetArch()
    arch.refreshGraph()

    results["Capacity"] = capacity
    results["Distance"] = distance
    results["ElapsedTime"][label] = max(parallelOpsMap.keys())
    results["Operations"][label] = len(allOps)
    results["MeanConcurrency"][label] = np.mean([len(op.operations) for op in parallelOpsMap.values()])
    results["QubitOperations"][label] = len(instructions)
    results["LogicalErrorRates"][label] = logicalErrors
    results["PhysicalZErrorRates"][label] = physicalZErrors
    results["PhysicalXErrorRates"][label] = physicalXErrors


    trapSet = set()
    junctionSet = set()
    for op in allOps:
        for c in op.involvedComponents:
            if isinstance(c, Trap):
                trapSet.add(c)
            elif isinstance(c, Junction):
                junctionSet.add(c)

    # Every zone can contain up to two qubits
    # Njz = 1*Nj, Nlz = Nl*k
    # The number of zones  N = 1*Nj+k*Nl
    Njz = len(junctionSet) # each junction is one zone
    Nlz = len(trapSet)*capacity # each trap is k zones

    # Njz = int(np.ceil(nqubitsNeeded / (2*(capacity-1))) )# 2 traps per junction
    # Nlz = nqubitsNeeded-Njz
    Nde = NDE_LZ*Nlz+NDE_JZ*Njz
    Nse = NSE_Z*(Njz+Nlz)

    Num_electrodes = Nde+Nse
    Num_DACs = Num_electrodes
    results["DACs"][label] = Num_DACs
    results["Electrodes"][label] = Num_electrodes

    logger.info(f"{distance} {capacity} {label} = {results}")
    
    logger.info(f"Finished processing for distance {distance} and capacity {capacity}")
    return results

process_circuit(5,2,[1.0],100_000)
