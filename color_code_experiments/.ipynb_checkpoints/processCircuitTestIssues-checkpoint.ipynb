# %%
import sys
import os
# Tweak to ensure cwd is at root of repo
os.chdir('..')
print(os.getcwd())
# Out:
# C:\Users\monam\OneDrive\Desktop\UNI\II\PartIIProject\CST-Part-II-Project-Code

# %%
from src.simulator.qccd_circuit import process_circuit

ds = [3,5,7]

for d in ds: 
    print(process_circuit(d,2,[1.0],100_000)) 
    #print(process_circuit_wise_arch(d,c,[1.0], 100_000)) 
    print('\n')
# Out:
# {'ElapsedTime': {'Forwarding': 0.004085000000000001}, 'Operations': {'Forwarding': 466}, 'MeanConcurrency': {'Forwarding': np.float64(6.781818181818182)}, 'QubitOperations': {'Forwarding': 178}, 'LogicalErrorRates': {'Forwarding': [0.05481]}, 'PhysicalZErrorRates': {'Forwarding': [np.float64(0.006711326100063682)]}, 'PhysicalXErrorRates': {'Forwarding': [np.float64(0.006163226932548814)]}, 'Electrodes': {'Forwarding': 980}, 'DACs': {'Forwarding': 980}, 'Capacity': 2, 'Distance': 3}
#
#
# {'ElapsedTime': {'Forwarding': 0.004085000000000001}, 'Operations': {'Forwarding': 1530}, 'MeanConcurrency': {'Forwarding': np.float64(20.115151515151513)}, 'QubitOperations': {'Forwarding': 570}, 'LogicalErrorRates': {'Forwarding': [0.02013]}, 'PhysicalZErrorRates': {'Forwarding': [np.float64(0.007041585573227546)]}, 'PhysicalXErrorRates': {'Forwarding': [np.float64(0.006418054713602888)]}, 'Electrodes': {'Forwarding': 2800}, 'DACs': {'Forwarding': 2800}, 'Capacity': 2, 'Distance': 5}
#
#
# {'ElapsedTime': {'Forwarding': 0.004080000000000001}, 'Operations': {'Forwarding': 3194}, 'MeanConcurrency': {'Forwarding': np.float64(39.66257668711656)}, 'QubitOperations': {'Forwarding': 1178}, 'LogicalErrorRates': {'Forwarding': [0.01356]}, 'PhysicalZErrorRates': {'Forwarding': [np.float64(0.007176006624135872)]}, 'PhysicalXErrorRates': {'Forwarding': [np.float64(0.006528395848468784)]}, 'Electrodes': {'Forwarding': 5500}, 'DACs': {'Forwarding': 5500}, 'Capacity': 2, 'Distance': 7}

# %%
from src.simulator.qccd_circuit import *
from src.color_code_utils.color_code_circuits.color_code_circuit_666 import *

# testing the color code versions
ds = [9]
#erroring 
for d in ds:
    print(process_color_code_circuit(d,10,[1.0],100_000, (6,6,6)))
    print('\n')
    
"""
#ccobj = ColorCodeCircuit666(3,2)
qccd = QCCDCircuit.generate_color_code(5,2,(6,6,6))
print(f'before circuitString: {qccd}')
print(f'after circuitString: {qccd.circuitString()}')
#print(qccd.dataQubitsIdxs)
qccd._parseCircuitString(qccd.dataQubitsIdxs)
#print(qccd._measurementIons)
#print(qccd._dataIons)
#print(qccd._ionMapping)
#the measurement qubits aren't being picked up for some reason
"""
# Out:
# C:\Users\monam\OneDrive\Desktop\UNI\II\PartIIProject\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\monam\OneDrive\Desktop\UNI\II\PartIIProject\.venv\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 8
#       6 #erroring
#       7 for d in ds:
# ----> 8     print(process_color_code_circuit(d,10,[1.0],100_000, (6,6,6)))
#       9     print('\n')
#      11 """
#      12 #ccobj = ColorCodeCircuit666(3,2)
#      13 qccd = QCCDCircuit.generate_color_code(5,2,(6,6,6))
#    (...)     21 #the measurement qubits aren't being picked up for some reason
#      22 """
#
# File ~\OneDrive\Desktop\UNI\II\PartIIProject\CST-Part-II-Project-Code\src\simulator\qccd_circuit.py:760, in process_color_code_circuit(distance, capacity, gate_improvements, num_shots, tesselation)
#     756 nrowsNeeded = int(np.sqrt(nqubitsNeeded))+2
#     758 logger.info(f"Processing circuit with {nqubitsNeeded} qubits and {nrowsNeeded} rows")
# --> 760 arch, (instructions, _) = circuit.processCircuitAugmentedGrid(rows=nrowsNeeded, cols=nrowsNeeded, trapCapacity=capacity, dataQubitIdxs=circuit.dataQubitsIdxs)
#     762 arch.refreshGraph()
#     764 results = {"ElapsedTime": {}, "Operations": {}, "MeanConcurrency": {}, "QubitOperations": {}, "LogicalErrorRates": {}, "PhysicalZErrorRates": {}, "PhysicalXErrorRates": {}, "Electrodes": {}, "DACs": {}}
#
# File ~\OneDrive\Desktop\UNI\II\PartIIProject\CST-Part-II-Project-Code\src\simulator\qccd_circuit.py:350, in QCCDCircuit.processCircuitAugmentedGrid(self, trapCapacity, rows, cols, padding, dataQubitIdxs)
#     347 if (trapCapacity-1) * ((rows-1) * (2*cols-1)+cols) < len(self._ionMapping):
#     348     raise ValueError("processCircuit: not enough traps")
# --> 350 clusters=regularPartition(self._measurementIons, self._dataIons, trapCapacity)
#     352 cs, rs = cols, rows
#     353 allGridPos = []
#
# File ~\OneDrive\Desktop\UNI\II\PartIIProject\CST-Part-II-Project-Code\src\compiler\qccd_qubits_to_ions.py:62, in regularPartition(measurementIons, dataIons, trapCapacity)
#      60 clusters = list(clustersD)
#      61 for clusterM in clustersM:
# ---> 62     cl = min(clusters, key=lambda c: (c[1][0]-clusterM[1][0])**2+(c[1][1]-clusterM[1][1])**2)
#      63     cIons = list(cl[0])+list(clusterM[0])
#      64     rD = len(cl[0])/len(cIons)
#
# File ~\OneDrive\Desktop\UNI\II\PartIIProject\CST-Part-II-Project-Code\src\compiler\qccd_qubits_to_ions.py:62, in regularPartition.<locals>.<lambda>(c)
#      60 clusters = list(clustersD)
#      61 for clusterM in clustersM:
# ---> 62     cl = min(clusters, key=lambda c: (c[1][0]-clusterM[1][0])**2+(c[1][1]-clusterM[1][1])**2)
#      63     cIons = list(cl[0])+list(clusterM[0])
#      64     rD = len(cl[0])/len(cIons)
#
# IndexError: invalid index to scalar variable.

# %%
from src.color_code_utils.color_code_circuits.color_code_chrom_circuit_666 import *


ccobj = ColorCodeChromCircuit666(3,2)
qccd = QCCDCircuit.generate_color_code(5,2,(6,6,6))
print(f'before circuitString: {qccd}')
print(f'after circuitString: {qccd.circuitString()}')
#print(qccd.dataQubitsIdxs)
qccd._parseCircuitString(qccd.dataQubitsIdxs)
print(qccd._measurementIons)
print(qccd._dataIons)
print(qccd._ionMapping)
#the measurement qubits aren't being picked up for some reason
# Out:
# before circuitString: QUBIT_COORDS(0, 0) 0
# QUBIT_COORDS(2, 0) 1
# QUBIT_COORDS(2, 2) 2
# QUBIT_COORDS(3, 1) 3
# QUBIT_COORDS(3, 3) 4
# QUBIT_COORDS(5, 1) 5
# QUBIT_COORDS(5, 3) 6
# QUBIT_COORDS(5, 5) 7
# QUBIT_COORDS(6, 0) 8
# QUBIT_COORDS(6, 2) 9
# QUBIT_COORDS(6, 4) 10
# QUBIT_COORDS(6, 6) 11
# QUBIT_COORDS(8, 0) 12
# QUBIT_COORDS(8, 2) 13
# QUBIT_COORDS(8, 4) 14
# QUBIT_COORDS(9, 1) 15
# QUBIT_COORDS(9, 3) 16
# QUBIT_COORDS(11, 1) 17
# QUBIT_COORDS(12, 0) 18
# MPP Z0*Z1*Z2*Z3*Z4*Z5*Z6*Z7*Z8*Z9*Z10*Z11*Z12*Z13*Z14*Z15*Z16*Z17*Z18
# OBSERVABLE_INCLUDE(0) rec[-1]
# MPP X1*X3*X5*X8 X12*X15*X17*X18 X0*X1*X2*X3 X5*X8*X9*X12*X13*X15 X2*X3*X4*X5*X6*X9 X13*X15*X16*X17 X6*X9*X10*X13*X14*X16 X4*X6*X7*X10 X7*X10*X11*X14 Z1*Z3*Z5*Z8 Z12*Z15*Z17*Z18 Z0*Z1*Z2*Z3 Z5*Z8*Z9*Z12*Z13*Z15 Z2*Z3*Z4*Z5*Z6*Z9 Z13*Z15*Z16*Z17 Z6*Z9*Z10*Z13*Z14*Z16 Z4*Z6*Z7*Z10 Z7*Z10*Z11*Z14
# SHIFT_COORDS(0, 0, 1)
# TICK
# MPP X1*X3*X5*X8 X12*X15*X17*X18 X0*X1*X2*X3 X5*X8*X9*X12*X13*X15 X2*X3*X4*X5*X6*X9 X13*X15*X16*X17 X6*X9*X10*X13*X14*X16 X4*X6*X7*X10 X7*X10*X11*X14 Z1*Z3*Z5*Z8 Z12*Z15*Z17*Z18 Z0*Z1*Z2*Z3 Z5*Z8*Z9*Z12*Z13*Z15 Z2*Z3*Z4*Z5*Z6*Z9 Z13*Z15*Z16*Z17 Z6*Z9*Z10*Z13*Z14*Z16 Z4*Z6*Z7*Z10 Z7*Z10*Z11*Z14
# DETECTOR(4, 0.5, 0, 1) rec[-18] rec[-36]
# DETECTOR(10, 0.5, 0, 1) rec[-17] rec[-35]
# DETECTOR(1.75, 0.75, 0, 2) rec[-16] rec[-34]
# DETECTOR(7, 1, 0, 2) rec[-15] rec[-33]
# DETECTOR(4, 2, 0, 0) rec[-14] rec[-32]
# DETECTOR(9.25, 1.75, 0, 0) rec[-13] rec[-31]
# DETECTOR(7, 3, 0, 1) rec[-12] rec[-30]
# DETECTOR(4.75, 3.75, 0, 2) rec[-11] rec[-29]
# DETECTOR(6.25, 4.75, 0, 0) rec[-10] rec[-28]
# DETECTOR(4, 0.5, 0, 4) rec[-9] rec[-27]
# DETECTOR(10, 0.5, 0, 4) rec[-8] rec[-26]
# DETECTOR(1.75, 0.75, 0, 5) rec[-7] rec[-25]
# DETECTOR(7, 1, 0, 5) rec[-6] rec[-24]
# DETECTOR(4, 2, 0, 3) rec[-5] rec[-23]
# DETECTOR(9.25, 1.75, 0, 3) rec[-4] rec[-22]
# DETECTOR(7, 3, 0, 4) rec[-3] rec[-21]
# DETECTOR(4.75, 3.75, 0, 5) rec[-2] rec[-20]
# DETECTOR(6.25, 4.75, 0, 3) rec[-1] rec[-19]
# SHIFT_COORDS(0, 0, 1)
# TICK
# MPP X1*X3*X5*X8 X12*X15*X17*X18 X0*X1*X2*X3 X5*X8*X9*X12*X13*X15 X2*X3*X4*X5*X6*X9 X13*X15*X16*X17 X6*X9*X10*X13*X14*X16 X4*X6*X7*X10 X7*X10*X11*X14 Z1*Z3*Z5*Z8 Z12*Z15*Z17*Z18 Z0*Z1*Z2*Z3 Z5*Z8*Z9*Z12*Z13*Z15 Z2*Z3*Z4*Z5*Z6*Z9 Z13*Z15*Z16*Z17 Z6*Z9*Z10*Z13*Z14*Z16 Z4*Z6*Z7*Z10 Z7*Z10*Z11*Z14
# DETECTOR(4, 0.5, 0, 1) rec[-18] rec[-36]
# DETECTOR(10, 0.5, 0, 1) rec[-17] rec[-35]
# DETECTOR(1.75, 0.75, 0, 2) rec[-16] rec[-34]
# DETECTOR(7, 1, 0, 2) rec[-15] rec[-33]
# DETECTOR(4, 2, 0, 0) rec[-14] rec[-32]
# DETECTOR(9.25, 1.75, 0, 0) rec[-13] rec[-31]
# DETECTOR(7, 3, 0, 1) rec[-12] rec[-30]
# DETECTOR(4.75, 3.75, 0, 2) rec[-11] rec[-29]
# DETECTOR(6.25, 4.75, 0, 0) rec[-10] rec[-28]
# DETECTOR(4, 0.5, 0, 4) rec[-9] rec[-27]
# DETECTOR(10, 0.5, 0, 4) rec[-8] rec[-26]
# DETECTOR(1.75, 0.75, 0, 5) rec[-7] rec[-25]
# DETECTOR(7, 1, 0, 5) rec[-6] rec[-24]
# DETECTOR(4, 2, 0, 3) rec[-5] rec[-23]
# DETECTOR(9.25, 1.75, 0, 3) rec[-4] rec[-22]
# DETECTOR(7, 3, 0, 4) rec[-3] rec[-21]
# DETECTOR(4.75, 3.75, 0, 5) rec[-2] rec[-20]
# DETECTOR(6.25, 4.75, 0, 3) rec[-1] rec[-19]
# SHIFT_COORDS(0, 0, 1)
# TICK
# MPP Z0*Z1*Z2*Z3*Z4*Z5*Z6*Z7*Z8*Z9*Z10*Z11*Z12*Z13*Z14*Z15*Z16*Z17*Z18
# OBSERVABLE_INCLUDE(0) rec[-1]
# after circuitString: ['QUBIT_COORDS(0, 0) 0', 'QUBIT_COORDS(2, 0) 1', 'QUBIT_COORDS(2, 2) 2', 'QUBIT_COORDS(3, 1) 3', 'QUBIT_COORDS(3, 3) 4', 'QUBIT_COORDS(5, 1) 5', 'QUBIT_COORDS(5, 3) 6', 'QUBIT_COORDS(5, 5) 7', 'QUBIT_COORDS(6, 0) 8', 'QUBIT_COORDS(6, 2) 9', 'QUBIT_COORDS(6, 4) 10', 'QUBIT_COORDS(6, 6) 11', 'QUBIT_COORDS(8, 0) 12', 'QUBIT_COORDS(8, 2) 13', 'QUBIT_COORDS(8, 4) 14', 'QUBIT_COORDS(9, 1) 15', 'QUBIT_COORDS(9, 3) 16', 'QUBIT_COORDS(11, 1) 17', 'QUBIT_COORDS(12, 0) 18', 'CNOT 1 0', 'CNOT 2 0', 'CNOT 3 0', 'CNOT 4 0', 'CNOT 5 0', 'CNOT 6 0', 'CNOT 7 0', 'CNOT 8 0', 'CNOT 9 0', 'CNOT 10 0', 'CNOT 11 0', 'CNOT 12 0', 'CNOT 13 0', 'CNOT 14 0', 'CNOT 15 0', 'CNOT 16 0', 'CNOT 17 0', 'CNOT 18 0', 'BARRIER', 'M 0', 'CNOT 1 0', 'CNOT 2 0', 'CNOT 3 0', 'CNOT 4 0', 'CNOT 5 0', 'CNOT 6 0', 'CNOT 7 0', 'CNOT 8 0', 'CNOT 9 0', 'CNOT 10 0', 'CNOT 11 0', 'CNOT 12 0', 'CNOT 13 0', 'CNOT 14 0', 'CNOT 15 0', 'CNOT 16 0', 'CNOT 17 0', 'CNOT 18 0', 'BARRIER', 'H 1', 'H 3', 'H 5', 'H 8', 'H 12', 'H 15', 'H 17', 'H 18', 'CNOT 3 1', 'CNOT 5 1', 'CNOT 8 1', 'CNOT 15 12', 'CNOT 17 12', 'CNOT 18 12', 'BARRIER', 'M 1', 'M 12', 'CNOT 3 1', 'CNOT 5 1', 'CNOT 8 1', 'CNOT 15 12', 'CNOT 17 12', 'CNOT 18 12', 'BARRIER', 'H 1', 'H 3', 'H 5', 'H 8', 'H 12', 'H 15', 'H 17', 'H 18', 'H 0', 'H 1', 'H 2', 'H 3', 'H 5', 'H 8', 'H 9', 'H 12', 'H 13', 'H 15', 'CNOT 1 0', 'CNOT 2 0', 'CNOT 3 0', 'CNOT 8 5', 'CNOT 9 5', 'CNOT 12 5', 'CNOT 13 5', 'CNOT 15 5', 'BARRIER', 'M 0', 'M 5', 'CNOT 1 0', 'CNOT 2 0', 'CNOT 3 0', 'CNOT 8 5', 'CNOT 9 5', 'CNOT 12 5', 'CNOT 13 5', 'CNOT 15 5', 'BARRIER', 'H 0', 'H 1', 'H 2', 'H 3', 'H 5', 'H 8', 'H 9', 'H 12', 'H 13', 'H 15', 'H 2', 'H 3', 'H 4', 'H 5', 'H 6', 'H 9', 'H 13', 'H 15', 'H 16', 'H 17', 'CNOT 3 2', 'CNOT 4 2', 'CNOT 5 2', 'CNOT 6 2', 'CNOT 9 2', 'CNOT 15 13', 'CNOT 16 13', 'CNOT 17 13', 'BARRIER', 'M 2', 'M 13', 'CNOT 3 2', 'CNOT 4 2', 'CNOT 5 2', 'CNOT 6 2', 'CNOT 9 2', 'CNOT 15 13', 'CNOT 16 13', 'CNOT 17 13', 'BARRIER', 'H 2', 'H 3', 'H 4', 'H 5', 'H 6', 'H 9', 'H 13', 'H 15', 'H 16', 'H 17', 'H 6', 'H 9', 'H 10', 'H 13', 'H 14', 'H 16', 'CNOT 9 6', 'CNOT 10 6', 'CNOT 13 6', 'CNOT 14 6', 'CNOT 16 6', 'BARRIER', 'M 6', 'CNOT 9 6', 'CNOT 10 6', 'CNOT 13 6', 'CNOT 14 6', 'CNOT 16 6', 'BARRIER', 'H 6', 'H 9', 'H 10', 'H 13', 'H 14', 'H 16', 'H 4', 'H 6', 'H 7', 'H 10', 'CNOT 6 4', 'CNOT 7 4', 'CNOT 10 4', 'BARRIER', 'M 4', 'CNOT 6 4', 'CNOT 7 4', 'CNOT 10 4', 'BARRIER', 'H 4', 'H 6', 'H 7', 'H 10', 'H 7', 'H 10', 'H 11', 'H 14', 'CNOT 10 7', 'CNOT 11 7', 'CNOT 14 7', 'CNOT 3 1', 'CNOT 5 1', 'CNOT 8 1', 'CNOT 15 12', 'CNOT 17 12', 'CNOT 18 12', 'BARRIER', 'M 7', 'M 1', 'M 12', 'CNOT 10 7', 'CNOT 11 7', 'CNOT 14 7', 'CNOT 3 1', 'CNOT 5 1', 'CNOT 8 1', 'CNOT 15 12', 'CNOT 17 12', 'CNOT 18 12', 'BARRIER', 'H 7', 'H 10', 'H 11', 'H 14', 'CNOT 1 0', 'CNOT 2 0', 'CNOT 3 0', 'CNOT 8 5', 'CNOT 9 5', 'CNOT 12 5', 'CNOT 13 5', 'CNOT 15 5', 'BARRIER', 'M 0', 'M 5', 'CNOT 1 0', 'CNOT 2 0', 'CNOT 3 0', 'CNOT 8 5', 'CNOT 9 5', 'CNOT 12 5', 'CNOT 13 5', 'CNOT 15 5', 'CNOT 3 2', 'CNOT 4 2', 'CNOT 5 2', 'CNOT 6 2', 'CNOT 9 2', 'CNOT 15 13', 'CNOT 16 13', 'CNOT 17 13', 'BARRIER', 'M 2', 'M 13', 'CNOT 3 2', 'CNOT 4 2', 'CNOT 5 2', 'CNOT 6 2', 'CNOT 9 2', 'CNOT 15 13', 'CNOT 16 13', 'CNOT 17 13', 'CNOT 9 6', 'CNOT 10 6', 'CNOT 13 6', 'CNOT 14 6', 'CNOT 16 6', 'BARRIER', 'M 6', 'CNOT 9 6', 'CNOT 10 6', 'CNOT 13 6', 'CNOT 14 6', 'CNOT 16 6', 'CNOT 6 4', 'CNOT 7 4', 'CNOT 10 4', 'BARRIER', 'M 4', 'CNOT 6 4', 'CNOT 7 4', 'CNOT 10 4', 'CNOT 10 7', 'CNOT 11 7', 'CNOT 14 7', 'BARRIER', 'M 7', 'CNOT 10 7', 'CNOT 11 7', 'CNOT 14 7', 'BARRIER', 'H 1', 'H 3', 'H 5', 'H 8', 'H 12', 'H 15', 'H 17', 'H 18', 'CNOT 3 1', 'CNOT 5 1', 'CNOT 8 1', 'CNOT 15 12', 'CNOT 17 12', 'CNOT 18 12', 'BARRIER', 'M 1', 'M 12', 'CNOT 3 1', 'CNOT 5 1', 'CNOT 8 1', 'CNOT 15 12', 'CNOT 17 12', 'CNOT 18 12', 'BARRIER', 'H 1', 'H 3', 'H 5', 'H 8', 'H 12', 'H 15', 'H 17', 'H 18', 'H 0', 'H 1', 'H 2', 'H 3', 'H 5', 'H 8', 'H 9', 'H 12', 'H 13', 'H 15', 'CNOT 1 0', 'CNO ...
# []
# %%
import stim
from src.color_code_utils.color_code_circuits.color_code_circuit_666 import *
with open("./preparation/testcirc.txt") as f:
    circstr = f.read()


cc = ColorCodeCircuit666(9,2)
#print(cc.get_circuit())
#print(f' qubits: {(cc.qubits)}')
#print(f' ancilla: {cc.ancilla}')
circuit = stim.Circuit(circstr)
# Run this in a notebook
circuit.diagram("detslice", filter_coords=['D36','D40','D43','D61', 'D70', 'D73'])
#filter_coords=['D36', 'D43'])

# If you know the failing detectors are [19, 37, 43]
matches = circuit.explain_detector_error_model_errors()

for match in matches:
    print(match)
# Out:
# [stim.ExplainedError(dem_error_terms=(stim.DemTargetWithCoords(dem_target=stim.DemTarget('D0'), coords=[4, 0, 1, 4]),), circuit_error_locations=(stim.CircuitErrorLocation(tick_offset=3, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(7), [4, 2]),stim.GateTargetWithCoords(stim.target_x(9), [5, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0153113], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(7, [4, 2]),stim.GateTargetWithCoords(9, [5, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=961,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=2, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(1), [1, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE1', args=[0.0132581], target_range_start=2, target_range_end=3, targets_in_range=(stim.GateTargetWithCoords(1, [1, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=767,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=2, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(1), [1, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE1', args=[0.0132581], target_range_start=1, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(1, [1, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=767,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=2, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(1), [1, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE1', args=[0.0132581], target_range_start=0, target_range_end=1, targets_in_range=(stim.GateTargetWithCoords(1, [1, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=767,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),)),
#  stim.ExplainedError(dem_error_terms=(stim.DemTargetWithCoords(dem_target=stim.DemTarget('D0'), coords=[4, 0, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D1'), coords=[10, 0, 1, 4]),), circuit_error_locations=(stim.CircuitErrorLocation(tick_offset=3, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(16), [7, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0452342], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(16, [7, 1]),stim.GateTargetWithCoords(7, [4, 2]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=930,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=2, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(16), [7, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE1', args=[0.0142135], target_range_start=2, target_range_end=3, targets_in_range=(stim.GateTargetWithCoords(16, [7, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=772,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=2, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(16), [7, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE1', args=[0.0142135], target_range_start=1, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(16, [7, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=772,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=2, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(16), [7, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE1', args=[0.0142135], target_range_start=0, target_range_end=1, targets_in_range=(stim.GateTargetWithCoords(16, [7, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=772,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),)),
#  stim.ExplainedError(dem_error_terms=(stim.DemTargetWithCoords(dem_target=stim.DemTarget('D0'), coords=[4, 0, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D1'), coords=[10, 0, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D4'), coords=[1, 1, 1, 5]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D5'), coords=[7, 1, 1, 5]),), circuit_error_locations=(stim.CircuitErrorLocation(tick_offset=3, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(16), [7, 1]),stim.GateTargetWithCoords(stim.target_x(7), [4, 2]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0452342], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(16, [7, 1]),stim.GateTargetWithCoords(7, [4, 2]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=930,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),)),
#  stim.ExplainedError(dem_error_terms=(stim.DemTargetWithCoords(dem_target=stim.DemTarget('D0'), coords=[4, 0, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D1'), coords=[10, 0, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D4'), coords=[1, 1, 1, 5]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D5'), coords=[7, 1, 1, 5]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D35'), coords=[7, 1, 1, 2]),), circuit_error_locations=(stim.CircuitErrorLocation(tick_offset=3, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(16), [7, 1]),stim.GateTargetWithCoords(stim.target_x(7), [4, 2]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0452342], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(16, [7, 1]),stim.GateTargetWithCoords(7, [4, 2]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=930,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),)),
#  stim.ExplainedError(dem_error_terms=(stim.DemTargetWithCoords(dem_target=stim.DemTarget('D0'), coords=[4, 0, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D1'), coords=[10, 0, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D4'), coords=[1, 1, 1, 5]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D5'), coords=[7, 1, 1, 5]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D35'), coords=[7, 1, 1, 2]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D38'), coords=[4, 2, 1, 0]),), circuit_error_locations=(stim.CircuitErrorLocation(tick_offset=3, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(16), [7, 1]),stim.GateTargetWithCoords(stim.target_y(7), [4, 2]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0452342], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(16, [7, 1]),stim.GateTargetWithCoords(7, [4, 2]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=930,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),)),
#  stim.ExplainedError(dem_error_terms=(stim.DemTargetWithCoords(dem_target=stim.DemTarget('D0'), coords=[4, 0, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D1'), coords=[10, 0, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D4'), coords=[1, 1, 1, 5]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D5'), coords=[7, 1, 1, 5]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D38'), coords=[4, 2, 1, 0]),), circuit_error_locations=(stim.CircuitErrorLocation(tick_offset=3, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(16), [7, 1]),stim.GateTargetWithCoords(stim.target_y(7), [4, 2]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0452342], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(16, [7, 1]),stim.GateTargetWithCoords(7, [4, 2]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=930,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),)),
#  stim.ExplainedError(dem_error_terms=(stim.DemTargetWithCoords(dem_target=stim.DemTarget('D0'), coords=[4, 0, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D1'), coords=[10, 0, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D35'), coords=[7, 1, 1, 2]),), circuit_error_locations=(stim.CircuitErrorLocation(tick_offset=3, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(16), [7, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0452342], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(16, [7, 1]),stim.GateTargetWithCoords(7, [4, 2]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=930,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=2, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(16), [7, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE1', args=[0.0142135], target_range_start=2, target_range_end=3, targets_in_range=(stim.GateTargetWithCoords(16, [7, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=772,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=2, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(16), [7, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE1', args=[0.0142135], target_range_start=1, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(16, [7, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=772,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=2, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(16), [7, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE1', args=[0.0142135], target_range_start=0, target_range_end=1, targets_in_range=(stim.GateTargetWithCoords(16, [7, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=772,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),)),
#  stim.ExplainedError(dem_error_terms=(stim.DemTargetWithCoords(dem_target=stim.DemTarget('D0'), coords=[4, 0, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D1'), coords=[10, 0, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D35'), coords=[7, 1, 1, 2]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D38'), coords=[4, 2, 1, 0]),), circuit_error_locations=(stim.CircuitErrorLocation(tick_offset=3, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(16), [7, 1]),stim.GateTargetWithCoords(stim.target_z(7), [4, 2]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0452342], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(16, [7, 1]),stim.GateTargetWithCoords(7, [4, 2]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=930,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),)),
#  stim.ExplainedError(dem_error_terms=(stim.DemTargetWithCoords(dem_target=stim.DemTarget('D0'), coords=[4, 0, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D1'), coords=[10, 0, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D38'), coords=[4, 2, 1, 0]),), circuit_error_locations=(stim.CircuitErrorLocation(tick_offset=3, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(16), [7, 1]),stim.GateTargetWithCoords(stim.target_z(7), [4, 2]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0452342], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(16, [7, 1]),stim.GateTargetWithCoords(7, [4, 2]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=930,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),)),
#  stim.ExplainedError(dem_error_terms=(stim.DemTargetWithCoords(dem_target=stim.DemTarget('D0'), coords=[4, 0, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D4'), coords=[1, 1, 1, 5]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D8'), coords=[4, 2, 1, 3]),), circuit_error_locations=(stim.CircuitErrorLocation(tick_offset=7, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(4), [3, 1]),stim.GateTargetWithCoords(stim.target_x(7), [4, 2]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0144904], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(4, [3, 1]),stim.GateTargetWithCoords(7, [4, 2]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=2199,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=7, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(4), [3, 1]),stim.GateTargetWithCoords(stim.target_y(7), [4, 2]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0144904], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(4, [3, 1]),stim.GateTargetWithCoords(7, [4, 2]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=2199,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=6, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0153113], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(1, [1, 1]),stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1585,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=6, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(1), [1, 1]),stim.GateTargetWithCoords(stim.target_x(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0153113], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(1, [1, 1]),stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1585,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=6, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0153113], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(6, [4, 0]),stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1552,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=6, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(6), [4, 0]),stim.GateTargetWithCoords(stim.target_x(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0153113], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(6, [4, 0]),stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1552,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=5, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE1', args=[0.0151713], target_range_start=0, target_range_end=1, targets_in_range=(stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1331,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=4, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE1', args=[0.0151713], target_range_start=0, target_range_end=1, targets_in_range=(stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1136,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=1, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE1', args=[0.0132581], target_range_start=0, target_range_end=1, targets_in_range=(stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=597,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=1, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0153113], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(7, [4, 2]),stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=596,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=1, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(7), [4, 2]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0153113], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(7, [4, 2]),stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=596,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=1, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_z(7), [4, 2]),stim.GateTargetWithCoords(stim.target_y(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0153113], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(7, [4, 2]),stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=596,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=1, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(7), [4, 2]),stim.GateTargetWithCoords(stim.target_z(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0153113], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(7, [4, 2]),stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=596,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=1, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(7), [4, 2]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE1', args=[0.0141778], target_range_start=1, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(7, [4, 2]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=595,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=1, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(7), [4, 2]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE1', args=[0.0141778], target_range_start=0, target_range_end=1, targets_in_range=(stim.GateTargetWithCoords(7, [4, 2]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=595,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=0, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='X_ERROR', args=[0.005], target_range_start=0, target_range_end=1, targets_in_range=(stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=98,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),)),
#  stim.ExplainedError(dem_error_terms=(stim.DemTargetWithCoords(dem_target=stim.DemTarget('D0'), coords=[4, 0, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D4'), coords=[1, 1, 1, 5]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D8'), coords=[4, 2, 1, 3]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D30'), coords=[4, 0, 1, 1]),), circuit_error_locations=(stim.CircuitErrorLocation(tick_offset=6, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_z(6), [4, 0]),stim.GateTargetWithCoords(stim.target_x(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0153113], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(6, [4, 0]),stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1552,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=6, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(6), [4, 0]),stim.GateTargetWithCoords(stim.target_x(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0153113], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(6, [4, 0]),stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1552,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),)),
#  stim.ExplainedError(dem_error_terms=(stim.DemTargetWithCoords(dem_target=stim.DemTarget('D0'), coords=[4, 0, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D4'), coords=[1, 1, 1, 5]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D8'), coords=[4, 2, 1, 3]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D30'), coords=[4, 0, 1, 1]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D34'), coords=[1, 1, 1, 2]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D38'), coords=[4, 2, 1, 0]),), circuit_error_locations=(stim.CircuitErrorLocation(tick_offset=7, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(4), [3, 1]),stim.GateTargetWithCoords(stim.target_y(7), [4, 2]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0144904], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(4, [3, 1]),stim.GateTargetWithCoords(7, [4, 2]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=2199,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=7, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(4), [3, 1]),stim.GateTargetWithCoords(stim.target_x(7), [4, 2]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0144904], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(4, [3, 1]),stim.GateTargetWithCoords(7, [4, 2]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=2199,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=6, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0153113], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(1, [1, 1]),stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1585,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=6, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(1), [1, 1]),stim.GateTargetWithCoords(stim.target_y(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0153113], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(1, [1, 1]),stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1585,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=6, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0153113], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(6, [4, 0]),stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1552,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=6, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(6), [4, 0]),stim.GateTargetWithCoords(stim.target_y(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0153113], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(6, [4, 0]),stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1552,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=5, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE1', args=[0.0151713], target_range_start=0, target_range_end=1, targets_in_range=(stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1331,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),)),
#  stim.ExplainedError(dem_error_terms=(stim.DemTargetWithCoords(dem_target=stim.DemTarget('D0'), coords=[4, 0, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D4'), coords=[1, 1, 1, 5]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D8'), coords=[4, 2, 1, 3]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D30'), coords=[4, 0, 1, 1]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D38'), coords=[4, 2, 1, 0]),), circuit_error_locations=(stim.CircuitErrorLocation(tick_offset=6, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_z(1), [1, 1]),stim.GateTargetWithCoords(stim.target_y(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0153113], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(1, [1, 1]),stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1585,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=6, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(1), [1, 1]),stim.GateTargetWithCoords(stim.target_y(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0153113], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(1, [1, 1]),stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1585,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),)),
#  stim.ExplainedError(dem_error_terms=(stim.DemTargetWithCoords(dem_target=stim.DemTarget('D0'), coords=[4, 0, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D4'), coords=[1, 1, 1, 5]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D8'), coords=[4, 2, 1, 3]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D34'), coords=[1, 1, 1, 2]),), circuit_error_locations=(stim.CircuitErrorLocation(tick_offset=6, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_z(1), [1, 1]),stim.GateTargetWithCoords(stim.target_x(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0153113], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(1, [1, 1]),stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1585,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=6, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(1), [1, 1]),stim.GateTargetWithCoords(stim.target_x(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0153113], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(1, [1, 1]),stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1585,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),)),
#  stim.ExplainedError(dem_error_terms=(stim.DemTargetWithCoords(dem_target=stim.DemTarget('D0'), coords=[4, 0, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D4'), coords=[1, 1, 1, 5]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D8'), coords=[4, 2, 1, 3]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D34'), coords=[1, 1, 1, 2]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D38'), coords=[4, 2, 1, 0]),), circuit_error_locations=(stim.CircuitErrorLocation(tick_offset=6, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_z(6), [4, 0]),stim.GateTargetWithCoords(stim.target_y(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0153113], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(6, [4, 0]),stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1552,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=6, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(6), [4, 0]),stim.GateTargetWithCoords(stim.target_y(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0153113], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(6, [4, 0]),stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1552,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=4, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE1', args=[0.0151713], target_range_start=0, target_range_end=1, targets_in_range=(stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1136,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),)),
#  stim.ExplainedError(dem_error_terms=(stim.DemTargetWithCoords(dem_target=stim.DemTarget('D0'), coords=[4, 0, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D4'), coords=[1, 1, 1, 5]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D8'), coords=[4, 2, 1, 3]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D38'), coords=[4, 2, 1, 0]),), circuit_error_locations=(stim.CircuitErrorLocation(tick_offset=1, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE1', args=[0.0132581], target_range_start=0, target_range_end=1, targets_in_range=(stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=597,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=1, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0153113], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(7, [4, 2]),stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=596,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=1, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(7), [4, 2]),stim.GateTargetWithCoords(stim.target_z(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0153113], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(7, [4, 2]),stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=596,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=1, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_z(7), [4, 2]),stim.GateTargetWithCoords(stim.target_x(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0153113], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(7, [4, 2]),stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=596,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=1, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(7), [4, 2]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0153113], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(7, [4, 2]),stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=596,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=1, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(7), [4, 2]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE1', args=[0.0141778], target_range_start=1, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(7, [4, 2]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=595,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=1, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(7), [4, 2]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE1', args=[0.0141778], target_range_start=0, target_range_end=1, targets_in_range=(stim.GateTargetWithCoords(7, [4, 2]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=595,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),)),
#  stim.ExplainedError(dem_error_terms=(stim.DemTargetWithCoords(dem_target=stim.DemTarget('D0'), coords=[4, 0, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D4'), coords=[1, 1, 1, 5]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D30'), coords=[4, 0, 1, 1]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D34'), coords=[1, 1, 1, 2]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D38'), coords=[4, 2, 1, 0]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D68'), coords=[4, 2, 2, 3]),), circuit_error_locations=(stim.CircuitErrorLocation(tick_offset=7, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(4), [3, 1]),stim.GateTargetWithCoords(stim.target_z(7), [4, 2]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0144904], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(4, [3, 1]),stim.GateTargetWithCoords(7, [4, 2]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=2199,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=7, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0144904], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(4, [3, 1]),stim.GateTargetWithCoords(7, [4, 2]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=2199,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=7, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE1', args=[0.0151713], target_range_start=1, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=2198,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=7, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(4), [3, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE1', args=[0.0151713], target_range_start=0, target_range_end=1, targets_in_range=(stim.GateTargetWithCoords(4, [3, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=2198,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),)),
#  stim.ExplainedError(dem_error_terms=(stim.DemTargetWithCoords(dem_target=stim.DemTarget('D0'), coords=[4, 0, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D4'), coords=[1, 1, 1, 5]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D30'), coords=[4, 0, 1, 1]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D34'), coords=[1, 1, 1, 2]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('L0'), coords=[]),), circuit_error_locations=(stim.CircuitErrorLocation(tick_offset=8, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(2), [2, 0]),stim.GateTargetWithCoords(stim.target_x(1), [1, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0145682], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(2, [2, 0]),stim.GateTargetWithCoords(1, [1, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=2382,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=4, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(2), [2, 0]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0133981], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(1, [1, 1]),stim.GateTargetWithCoords(2, [2, 0]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1134,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=3, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(2), [2, 0]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE1', args=[0.0132581], target_range_start=0, target_range_end=1, targets_in_range=(stim.GateTargetWithCoords(2, [2, 0]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=902,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=3, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(2), [2, 0]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0133981], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(6, [4, 0]),stim.GateTargetWithCoords(2, [2, 0]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=901,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=3, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(6), [4, 0]),stim.GateTargetWithCoords(stim.target_z(2), [2, 0]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0133981], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(6, [4, 0]),stim.GateTargetWithCoords(2, [2, 0]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=901,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),)),
#  stim.ExplainedError(dem_error_terms=(stim.DemTargetWithCoords(dem_target=stim.DemTarget('D0'), coords=[4, 0, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D4'), coords=[1, 1, 1, 5]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D30'), coords=[4, 0, 1, 1]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('L0'), coords=[]),), circuit_error_locations=(stim.CircuitErrorLocation(tick_offset=8, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(2), [2, 0]),stim.GateTargetWithCoords(stim.target_y(1), [1, 1]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0145682], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(2, [2, 0]),stim.GateTargetWithCoords(1, [1, 1]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=2382,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
# ...
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0145963], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(80, [19, 3]),stim.GateTargetWithCoords(86, [21, 3]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1433,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),)),
#  stim.ExplainedError(dem_error_terms=(stim.DemTargetWithCoords(dem_target=stim.DemTarget('D14'), coords=[19, 3, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D20'), coords=[19, 5, 1, 3]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D44'), coords=[19, 3, 1, 1]),), circuit_error_locations=(stim.CircuitErrorLocation(tick_offset=5, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(80), [19, 3]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0396953], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(81, [19, 5]),stim.GateTargetWithCoords(80, [19, 3]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1472,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=5, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(80), [19, 3]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0145963], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(80, [19, 3]),stim.GateTargetWithCoords(86, [21, 3]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1433,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=5, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(80), [19, 3]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE1', args=[0.0144272], target_range_start=1, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(80, [19, 3]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1432,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=5, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(80), [19, 3]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE1', args=[0.0144272], target_range_start=0, target_range_end=1, targets_in_range=(stim.GateTargetWithCoords(80, [19, 3]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1432,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),)),
#  stim.ExplainedError(dem_error_terms=(stim.DemTargetWithCoords(dem_target=stim.DemTarget('D14'), coords=[19, 3, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D20'), coords=[19, 5, 1, 3]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D44'), coords=[19, 3, 1, 1]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D47'), coords=[16, 4, 1, 2]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D50'), coords=[19, 5, 1, 0]),), circuit_error_locations=(stim.CircuitErrorLocation(tick_offset=8, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(84), [20, 4]),stim.GateTargetWithCoords(stim.target_y(81), [19, 5]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0160778], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(84, [20, 4]),stim.GateTargetWithCoords(81, [19, 5]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=2496,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),)),
#  stim.ExplainedError(dem_error_terms=(stim.DemTargetWithCoords(dem_target=stim.DemTarget('D14'), coords=[19, 3, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D20'), coords=[19, 5, 1, 3]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D44'), coords=[19, 3, 1, 1]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D50'), coords=[19, 5, 1, 0]),), circuit_error_locations=(stim.CircuitErrorLocation(tick_offset=8, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(84), [20, 4]),stim.GateTargetWithCoords(stim.target_x(81), [19, 5]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0160778], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(84, [20, 4]),stim.GateTargetWithCoords(81, [19, 5]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=2496,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=7, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(84), [20, 4]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0149622], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(80, [19, 3]),stim.GateTargetWithCoords(84, [20, 4]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=2008,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=7, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(80), [19, 3]),stim.GateTargetWithCoords(stim.target_y(84), [20, 4]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0149622], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(80, [19, 3]),stim.GateTargetWithCoords(84, [20, 4]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=2008,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=7, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_z(80), [19, 3]),stim.GateTargetWithCoords(stim.target_y(84), [20, 4]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0149622], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(80, [19, 3]),stim.GateTargetWithCoords(84, [20, 4]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=2008,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=7, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(80), [19, 3]),stim.GateTargetWithCoords(stim.target_y(84), [20, 4]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0149622], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(80, [19, 3]),stim.GateTargetWithCoords(84, [20, 4]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=2008,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=6, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(84), [20, 4]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE1', args=[0.0141778], target_range_start=0, target_range_end=1, targets_in_range=(stim.GateTargetWithCoords(84, [20, 4]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1634,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=5, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_z(81), [19, 5]),stim.GateTargetWithCoords(stim.target_y(80), [19, 3]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0396953], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(81, [19, 5]),stim.GateTargetWithCoords(80, [19, 3]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1472,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),)),
#  stim.ExplainedError(dem_error_terms=(stim.DemTargetWithCoords(dem_target=stim.DemTarget('D14'), coords=[19, 3, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D20'), coords=[19, 5, 1, 3]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D47'), coords=[16, 4, 1, 2]),), circuit_error_locations=(stim.CircuitErrorLocation(tick_offset=8, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(84), [20, 4]),stim.GateTargetWithCoords(stim.target_y(81), [19, 5]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0160778], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(84, [20, 4]),stim.GateTargetWithCoords(81, [19, 5]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=2496,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),)),
#  stim.ExplainedError(dem_error_terms=(stim.DemTargetWithCoords(dem_target=stim.DemTarget('D14'), coords=[19, 3, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D20'), coords=[19, 5, 1, 3]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D50'), coords=[19, 5, 1, 0]),), circuit_error_locations=(stim.CircuitErrorLocation(tick_offset=5, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_z(81), [19, 5]),stim.GateTargetWithCoords(stim.target_x(80), [19, 3]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0396953], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(81, [19, 5]),stim.GateTargetWithCoords(80, [19, 3]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1472,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=3, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(84), [20, 4]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0143177], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(81, [19, 5]),stim.GateTargetWithCoords(84, [20, 4]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1049,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=3, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_z(81), [19, 5]),stim.GateTargetWithCoords(stim.target_x(84), [20, 4]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0143177], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(81, [19, 5]),stim.GateTargetWithCoords(84, [20, 4]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1049,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=2, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(84), [20, 4]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE1', args=[0.0141778], target_range_start=3, target_range_end=4, targets_in_range=(stim.GateTargetWithCoords(84, [20, 4]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=850,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),)),
#  stim.ExplainedError(dem_error_terms=(stim.DemTargetWithCoords(dem_target=stim.DemTarget('D14'), coords=[19, 3, 1, 4]),stim.DemTargetWithCoords(dem_target=stim.DemTarget('D22'), coords=[16, 6, 1, 4]),), circuit_error_locations=(stim.CircuitErrorLocation(tick_offset=5, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(81), [19, 5]),stim.GateTargetWithCoords(stim.target_x(80), [19, 3]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0396953], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(81, [19, 5]),stim.GateTargetWithCoords(80, [19, 3]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1472,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=5, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(68), [16, 4]),stim.GateTargetWithCoords(stim.target_x(77), [18, 4]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0159602], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(68, [16, 4]),stim.GateTargetWithCoords(77, [18, 4]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1449,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=3, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_x(81), [19, 5]),stim.GateTargetWithCoords(stim.target_x(84), [20, 4]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0143177], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(81, [19, 5]),stim.GateTargetWithCoords(84, [20, 4]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1049,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),stim.CircuitErrorLocation(tick_offset=3, flipped_pauli_product=(stim.GateTargetWithCoords(stim.target_y(81), [19, 5]),stim.GateTargetWithCoords(stim.target_y(84), [20, 4]),), flipped_measurement=stim.FlippedMeasurement(
#      record_index=None,
#      observable=(),
#  ), instruction_targets=stim.CircuitTargetsInsideInstruction(gate='DEPOLARIZE2', args=[0.0143177], target_range_start=0, target_range_end=2, targets_in_range=(stim.GateTargetWithCoords(81, [19, 5]),stim.GateTargetWithCoords(84, [20, 4]),)), stack_frames=(stim.CircuitErrorLocationStackFrame(
#      instruction_offset=1049,
#      iteration_index=0,
#      instruction_repetitions_arg=0,
#  ),)),)),
#  ...]

# %%
cc.draw_layout()

# %%
qccd = QCCDCircuit.generated(
        "surface_code:rotated_memory_z",
        rounds=2,
        distance=3,)
#print(f'before circuitString: {qccd}')
#print(f'after circuitString: {qccd.circuitString()}')
qccd._parseCircuitString()
#print(qccd._measurementIons)
#print(qccd._dataIons)
#print(qccd._ionMapping)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 qccd = QCCDCircuit.generated(
#       2         "surface_code:rotated_memory_z",
#       3         rounds=2,
#       4         distance=3,)
#       5 #print(f'before circuitString: {qccd}')
#       6 #print(f'after circuitString: {qccd.circuitString()}')
#       7 qccd._parseCircuitString()
#
# NameError: name 'QCCDCircuit' is not defined

# %%
from color_code_stim import ColorCode

colorcode = ColorCode(d=9,rounds=2,circuit_type="tri")
#print(str(colorcode.circuit))
c = stim.Circuit(colorcode.circuit.__str__())
c.diagram("detslice-svg")
#qccd = QCCDCircuit(str(colorcode.circuit))
#print(f'before circuitString: {qccd.flattened().decomposed()}')
#print(f'after circuitString: {qccd.circuitString()}')
#qccd._parseCircuitString()
#print(f"parsed: {qccd._parseCircuitString()}")
# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json

file_path = r'.\data\surface_code_run.json'

with open(file_path, 'r') as f:
    raw_data = json.load(f)

records = []

# Assuming 'Forwarding' is your algorithm name based on your print output
label = 'Forwarding' 

# We need to extract these dictionaries from the raw JSON
# Depending on how your JSON is saved, keys might be inverted. 
# Based on your print(df) output, it looks like: data[Metric][Algorithm][d][capacity]
# Let's try to grab the dictionaries directly.
try:
    # Adjust these keys if your JSON nesting order is slightly different
    log_errs_dict = raw_data['LogicalErrorRates'][label]
    phys_x_dict = raw_data['PhysicalXErrorRates'][label]
    phys_z_dict = raw_data['PhysicalZErrorRates'][label]

# Iterate through the nested structure
for d_str, cap_dict in log_errs_dict.items():
    d = int(d_str)
    for cap_str, log_err_list in cap_dict.items():
        capacity = int(cap_str)
        
        # Get corresponding physical error rates
        phys_x_list = phys_x_dict[d_str][cap_str]
        phys_z_list = phys_z_dict[d_str][cap_str]
        
        # Combine the lists into rows for our DataFrame
        for i, log_err in enumerate(log_err_list):
            px = phys_x_list[i]
            pz = phys_z_list[i]
            
            # Standard practice: define p as the average or max of X/Z errors
            p_physical = (px + pz) / 2
            
            records.append({
                'd': d,
                'capacity': capacity,
                'p': p_physical,
                'logical_error_rate': log_err,
                'shots': 100000  # Hardcoded based on your previous snippets
            })

# Create the clean, flat DataFrame
df = pd.DataFrame(records)
print(df)
print("Flattened Data:")
print(df.head())

# --- 2. Plotting ---
plt.figure(figsize=(10, 7))

# Get unique distances and capacities
distances = sorted(df['d'].unique())
# If you have multiple capacities, you might want to filter for just one, e.g.:
# df = df[df['capacity'] == 13] 

for d in distances:
    # Filter data for this distance
    subset = df[df['d'] == d].sort_values('p')
    
    # Calculate Standard Error
    subset['std_err'] = np.sqrt(subset['logical_error_rate'] * (1 - subset['logical_error_rate']) / subset['shots'])
    
    plt.errorbar(
        subset['p'], 
        subset['logical_error_rate'], 
        yerr=subset['std_err'],
        label=f'd={d}', 
        marker='o', 
        capsize=3,
        linestyle='--'
    )

# --- 3. Styling ---
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Physical Error Rate ($p$)')
plt.ylabel('Logical Error Rate ($P_L$)')
plt.xlim(0.0005,1e-1)
plt.title(f'Surface Code')
plt.grid(True, which="both", ls="-", alpha=0.2)
plt.legend()

# Add a break-even line reference
lims = [
    min(plt.xlim()[0], plt.ylim()[0]),
    max(plt.xlim()[1], plt.ylim()[1])
]
plt.plot(lims, lims, 'k-', alpha=0.25, label="Break-even")

plt.show()
# Out:
#      d  capacity         p  logical_error_rate   shots
# 0    3        13  0.015912            0.146118  100000
# 1    3        13  0.003182            0.026905  100000
# 2    3        13  0.001591            0.013504  100000
# 3    3         9  0.013717            0.098578  100000
# 4    3         9  0.002743            0.008282  100000
# ..  ..       ...       ...                 ...     ...
# 199  9        60  0.008716            0.022531  100000
# 200  9        60  0.004358            0.001553  100000
# 201  9       120  0.069006            0.499268  100000
# 202  9       120  0.013801            0.090147  100000
# 203  9       120  0.006901            0.008011  100000
#
# [204 rows x 5 columns]
# Flattened Data:
#    d  capacity         p  logical_error_rate   shots
# 0  3        13  0.015912            0.146118  100000
# 1  3        13  0.003182            0.026905  100000
# 2  3        13  0.001591            0.013504  100000
# 3  3         9  0.013717            0.098578  100000
# 4  3         9  0.002743            0.008282  100000

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json

# --- 1. Load and Fix Data Structure ---
# Use raw string r'' to fix the SyntaxWarning about backslashes
file_path = r'.\data\color_code_first_run_data.json'

with open(file_path, 'r') as f:
    raw_data = json.load(f)

# The data is likely structured as: {Metric: {Algorithm: {Distance: {Capacity: [Values]}}}}
# We need to flatten this into a list of records.
records = []

# Assuming 'Forwarding' is your algorithm name based on your print output
algo_name = 'Forwarding' 

# We need to extract these dictionaries from the raw JSON
# Depending on how your JSON is saved, keys might be inverted. 
# Based on your print(df) output, it looks like: data[Metric][Algorithm][d][capacity]
# Let's try to grab the dictionaries directly.
try:
    # Adjust these keys if your JSON nesting order is slightly different
    log_errs_dict = raw_data['LogicalErrorRates'][algo_name]
    phys_x_dict = raw_data['PhysicalXErrorRates'][algo_name]
    phys_z_dict = raw_data['PhysicalZErrorRates'][algo_name]
except KeyError:
    # Fallback: maybe data is {Algorithm: {Metric: ...}}
    log_errs_dict = raw_data[algo_name]['LogicalErrorRates']
    phys_x_dict = raw_data[algo_name]['PhysicalXErrorRates']
    phys_z_dict = raw_data[algo_name]['PhysicalZErrorRates']

# Iterate through the nested structure
for d_str, cap_dict in log_errs_dict.items():
    d = int(d_str)
    for cap_str, log_err_list in cap_dict.items():
        capacity = int(cap_str)
        
        # Get corresponding physical error rates
        phys_x_list = phys_x_dict[d_str][cap_str]
        phys_z_list = phys_z_dict[d_str][cap_str]
        
        # Combine the lists into rows for our DataFrame
        for i, log_err in enumerate(log_err_list):
            px = phys_x_list[i]
            pz = phys_z_list[i]
            
            # Standard practice: define p as the average or max of X/Z errors
            p_physical = (px + pz) / 2
            
            records.append({
                'd': d,
                'capacity': capacity,
                'p': p_physical,
                'logical_error_rate': log_err,
                'shots': 100000  # Hardcoded based on your previous snippets
            })

# Create the clean, flat DataFrame
df = pd.DataFrame(records)
print(df)
print("Flattened Data:")
print(df.head())

# --- 2. Plotting ---
plt.figure(figsize=(10, 7))

# Get unique distances and capacities
distances = sorted(df['d'].unique())
# If you have multiple capacities, you might want to filter for just one, e.g.:
# df = df[df['capacity'] == 13] 

for d in distances:
    # Filter data for this distance
    subset = df[df['d'] == d].sort_values('p')
    
    # Calculate Standard Error
    subset['std_err'] = np.sqrt(subset['logical_error_rate'] * (1 - subset['logical_error_rate']) / subset['shots'])
    
    plt.errorbar(
        subset['p'], 
        subset['logical_error_rate'], 
        yerr=subset['std_err'],
        label=f'd={d}', 
        marker='o', 
        capsize=3,
        linestyle='--'
    )

# --- 3. Styling ---
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Physical Error Rate ($p$)')
plt.ylabel('Logical Error Rate ($P_L$)')
plt.xlim(0.0005,1e-1)
plt.title(f'Color Code First Run - own impl')
plt.grid(True, which="both", ls="-", alpha=0.2)
plt.legend()

# Add a break-even line reference
lims = [
    min(plt.xlim()[0], plt.ylim()[0]),
    max(plt.xlim()[1], plt.ylim()[1])
]
plt.plot(lims, lims, 'k-', alpha=0.25, label="Break-even")

plt.show()
