# %%
# %pip install sinter
# Out:
# Requirement already satisfied: sinter in c:\users\monam\onedrive\desktop\uni\ii\partiiproject\.venv\lib\site-packages (1.15.0)
# Requirement already satisfied: matplotlib in c:\users\monam\onedrive\desktop\uni\ii\partiiproject\.venv\lib\site-packages (from sinter) (3.10.7)
# Requirement already satisfied: numpy in c:\users\monam\onedrive\desktop\uni\ii\partiiproject\.venv\lib\site-packages (from sinter) (2.3.3)
# Requirement already satisfied: stim in c:\users\monam\onedrive\desktop\uni\ii\partiiproject\.venv\lib\site-packages (from sinter) (1.15.0)
# Requirement already satisfied: scipy in c:\users\monam\onedrive\desktop\uni\ii\partiiproject\.venv\lib\site-packages (from sinter) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\monam\onedrive\desktop\uni\ii\partiiproject\.venv\lib\site-packages (from matplotlib->sinter) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\monam\onedrive\desktop\uni\ii\partiiproject\.venv\lib\site-packages (from matplotlib->sinter) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\monam\onedrive\desktop\uni\ii\partiiproject\.venv\lib\site-packages (from matplotlib->sinter) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\monam\onedrive\desktop\uni\ii\partiiproject\.venv\lib\site-packages (from matplotlib->sinter) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\monam\onedrive\desktop\uni\ii\partiiproject\.venv\lib\site-packages (from matplotlib->sinter) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\monam\onedrive\desktop\uni\ii\partiiproject\.venv\lib\site-packages (from matplotlib->sinter) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\monam\onedrive\desktop\uni\ii\partiiproject\.venv\lib\site-packages (from matplotlib->sinter) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\monam\onedrive\desktop\uni\ii\partiiproject\.venv\lib\site-packages (from matplotlib->sinter) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\monam\onedrive\desktop\uni\ii\partiiproject\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->sinter) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import stim
import pymatching
import numpy as np
import sinter
from typing import List
import matplotlib.pyplot as plt

# %%
import sys
import os
# Add the parent directory to the Python path
sys.path.append(os.path.abspath('..'))

# %%
from src.utils.qccd_arch import *

# %%
arch = QCCDArch()

ionspacing = 5
trapspacing = 30
cool = 'red'
qubit = 'blue'
traps = []

for i in range(3):
    ions = [QubitIon(qubit, 'Q'), QubitIon(qubit, 'Q'), QubitIon(qubit, 'Q')]
    trap = arch.addManipulationTrap(x=i * trapspacing, y=0, ions=ions, color='grey', spacing=ionspacing, isHorizontal=True)
    traps.append(trap)

for t1,t2 in zip(traps[:-1], traps[1:]):
    arch.addEdge(t1,t2)

arch.refreshGraph()
fig,ax = plt.subplots()
arch.display(fig, ax, showLabels=True)

# %%
arch = QCCDArch()

ionspacing = 1
trapspacing = 6
qubit_colour = 'red'
qubit_colour = 'lightblue'
junction_colour = 'orange'
traps = []

ManipulationTrap.DEFAULT_SPACING = trapspacing
arch.SIZING = 0.5
ions11 = [QubitIon(qubit_colour, 'Q'), CoolingIon(qubit_colour, 'Q'), QubitIon(qubit_colour, 'Q'), CoolingIon(qubit_colour, 'Q')]
trap11 = arch.addManipulationTrap(x=0, y=0, ions=ions11, color='grey', spacing=ionspacing, isHorizontal=False)

ions12 = [QubitIon(qubit_colour, 'Q'), CoolingIon(qubit_colour, 'Q'), QubitIon(qubit_colour, 'Q'), CoolingIon(qubit_colour, 'Q')]
trap12 = arch.addManipulationTrap(x=trapspacing, y=0, ions=ions12, color='grey', spacing=ionspacing, isHorizontal=False)

junctionL = arch.addJunction(x=0, y=trapspacing, color=junction_colour)
junctionR = arch.addJunction(x=trapspacing, y=trapspacing, color=junction_colour)

ions21 = [QubitIon(qubit_colour, 'Q'), CoolingIon(qubit_colour, 'Q'), QubitIon(qubit_colour, 'Q'), CoolingIon(qubit_colour, 'Q')]
trap21 = arch.addManipulationTrap(x=0, y=2*trapspacing, ions=ions21, color='grey', spacing=ionspacing, isHorizontal=False)

ions22 = [QubitIon(qubit_colour, 'Q'), CoolingIon(qubit_colour, 'Q'), QubitIon(qubit_colour, 'Q'), CoolingIon(qubit_colour, 'Q')]
trap22 = arch.addManipulationTrap(x=trapspacing, y=2*trapspacing, ions=ions22, color='grey', spacing=ionspacing, isHorizontal=False)

crossing11 = arch.addEdge(trap11, junctionL)
arch.addEdge(trap12, junctionR)
crossing21 = arch.addEdge(trap21, junctionL)
arch.addEdge(trap22, junctionR)
arch.addEdge(junctionL, junctionR)

arch.refreshGraph()
# Display architecture
fig, ax = plt.subplots()
# Display architecture
arch.display(fig,ax, showLabels=False)

# %%
from src.compiler.qccd_parallelisation import *

ops = (
    Split.physicalOperation(trap11, crossing11), 
    Move.physicalOperation(crossing11),
    JunctionCrossing.physicalOperation(junctionL, crossing11),
    JunctionCrossing.physicalOperation(junctionL, crossing21),
    Move.physicalOperation(crossing21),
    Merge.physicalOperation(trap21, crossing21),
    GateSwap.physicalOperation(trap=trap21, ion1=ions21[0], ion2=ions21[2]),
    TwoQubitMSGate.physicalOperation(ion1=ions22[0], ion2=ions22[2],trap=trap22),
    OneQubitGate.physicalOperation(ion=ions12[0], trap=trap12),
    Measurement.physicalOperation(ion=ions12[0], trap=trap12),
    QubitReset.physicalOperation(ion=ions12[0],trap=trap12))
parallelOps = paralleliseOperationsSimple(ops)

print(parallelOps)
# Out:
# [<src.utils.qccd_operations.ParallelOperation object at 0x00000199BDB8BE00>, <src.utils.qccd_operations.ParallelOperation object at 0x00000199BFD61E50>, <src.utils.qccd_operations.ParallelOperation object at 0x00000199BFD61F90>, <src.utils.qccd_operations.ParallelOperation object at 0x00000199BD1A5F30>, <src.utils.qccd_operations.ParallelOperation object at 0x00000199A323FE10>, <src.utils.qccd_operations.ParallelOperation object at 0x00000199BDBACB90>, <src.utils.qccd_operations.ParallelOperation object at 0x00000199BDB32690>]

# %%
from src.simulator.qccd_circuit import *

noise = 1e-3
d=4
    
circuit = QCCDCircuit.generated(
    "surface_code:rotated_memory_z",
    rounds=1,
    distance=d,
    after_clifford_depolarization=noise,
    after_reset_flip_probability=noise,
    before_measure_flip_probability=noise,
    before_round_data_depolarization=noise,
)


rows = 4
cols = 4
capacity = 4

arch, (instructions,_) = circuit.processCircuitAugmentedGrid(rows=rows, cols=cols, trapCapacity=capacity)

for i in instructions:
    print(i.label+str([ion.idx for ion in i.ions]))

_capacities = [2,3]
rows = 10
cols = 10

label='part'
fig, axs = plt.subplots(1, len(_capacities))
for ax, capacity in zip(axs, _capacities):
    arch1, (instructions,_) = circuit.processCircuitAugmentedGrid(rows=rows, cols=cols, trapCapacity=capacity)
    arch1.ION_SIZE = 2000

    for idx, (ion, pos) in circuit._ionMapping.items():
        ion.set(ion.idx, pos[0], pos[1])

    arch1.refreshGraph()
    edgesDups = []
    edgesPos = []
    ionsInvolved = set()
    score = 0
    for op in instructions:
        if not isinstance(op, TwoQubitMSGate):
            continue
        if not ionsInvolved.isdisjoint(op.ions):
            score+=1
            ionsInvolved=set()
        edgesDups.append((op.ions, score))
        edgesPos.append((op.ionsActedIdxs, score))
        ionsInvolved=ionsInvolved.union(op.ions)
    scores = [score for ((ion1,ion2), score) in edgesDups]
    color_from_score = {s: (5+i*i)*2 for i, s in enumerate( sorted(list(set(scores)), reverse=True))}
    arch1._manipulationTraps.append(([(ion1.idx, ion2.idx) for ((ion1,ion2), score) in edgesDups], [color_from_score[score] for ((ion1,ion2), score) in edgesDups]))
    arch1.display(fig, ax, showLabels=False, showEdges=False, show_junction=False)
    ax.set_title(f"{label} {_capacities}")

#print(circuit.circuitString())
circuit.without_noise().diagram('timeline-svg')
# Out:
# QUBIT_RESET[19]
# QUBIT_RESET[10]
# QUBIT_RESET[23]
# QUBIT_RESET[12]
# QUBIT_RESET[30]
# QUBIT_RESET[42]
# QUBIT_RESET[33]
# QUBIT_RESET[36]
# QUBIT_RESET[52]
# QUBIT_RESET[55]
# QUBIT_RESET[45]
# QUBIT_RESET[46]
# QUBIT_RESET[62]
# QUBIT_RESET[63]
# QUBIT_RESET[66]
# QUBIT_RESET[67]
# QUBIT_RESET[17]
# QUBIT_RESET[21]
# QUBIT_RESET[18]
# QUBIT_RESET[9]
# QUBIT_RESET[22]
# QUBIT_RESET[28]
# QUBIT_RESET[29]
# QUBIT_RESET[41]
# QUBIT_RESET[32]
# QUBIT_RESET[35]
# QUBIT_RESET[51]
# QUBIT_RESET[54]
# QUBIT_RESET[44]
# QUBIT_RESET[61]
# QUBIT_RESET[65]
# RY[17]
# RX[17]
# RY[21]
# RX[21]
# RY[9]
# RX[9]
# RY[29]
# RX[29]
# RY[32]
# RX[32]
# RY[54]
# RX[54]
# RY[61]
# RX[61]
# RY[65]
# RX[65]
# RY[17]
# RX[17]
# RX[10]
# TWO_QUBIT_MS_GATE[17, 10]
# RY[17]
# RY[29]
# RX[29]
# RX[55]
# TWO_QUBIT_MS_GATE[29, 55]
# RY[29]
# RY[9]
# RX[9]
# RX[33]
# TWO_QUBIT_MS_GATE[9, 33]
# RY[9]
# RY[54]
# RX[54]
# RX[66]
# TWO_QUBIT_MS_GATE[54, 66]
# RY[54]
# RY[21]
# RX[21]
# RX[12]
# TWO_QUBIT_MS_GATE[21, 12]
# RY[21]
# RY[32]
# RX[32]
# RX[46]
# TWO_QUBIT_MS_GATE[32, 46]
# RY[32]
# RY[52]
# RX[52]
# RX[28]
# TWO_QUBIT_MS_GATE[52, 28]
# RY[52]
# RY[42]
# RX[42]
# RX[18]
# TWO_QUBIT_MS_GATE[42, 18]
# RY[42]
# RY[63]
# RX[63]
# RX[51]
# TWO_QUBIT_MS_GATE[63, 51]
# RY[63]
# RY[45]
# RX[45]
# RX[41]
# TWO_QUBIT_MS_GATE[45, 41]
# RY[45]
# RY[36]
# RX[36]
# RX[22]
# TWO_QUBIT_MS_GATE[36, 22]
# RY[36]
# RY[67]
# RX[67]
# RX[44]
# TWO_QUBIT_MS_GATE[67, 44]
# RY[67]
# RY[17]
# RX[17]
# RX[19]
# TWO_QUBIT_MS_GATE[17, 19]
# RY[17]
# RY[29]
# RX[29]
# RX[52]
# TWO_QUBIT_MS_GATE[29, 52]
# RY[29]
# RY[9]
# RX[9]
# RX[42]
# TWO_QUBIT_MS_GATE[9, 42]
# RY[9]
# RY[54]
# RX[54]
# RX[63]
# TWO_QUBIT_MS_GATE[54, 63]
# RY[54]
# RY[21]
# RX[21]
# RX[23]
# TWO_QUBIT_MS_GATE[21, 23]
# RY[21]
# RY[32]
# RX[32]
# RX[45]
# TWO_QUBIT_MS_GATE[32, 45]
# RY[32]
# RY[30]
# RX[30]
# RX[28]
# TWO_QUBIT_MS_GATE[30, 28]
# RY[30]
# RY[10]
# RX[10]
# RX[18]
# TWO_QUBIT_MS_GATE[10, 18]
# RY[10]
# RY[55]
# RX[55]
# RX[51]
# TWO_QUBIT_MS_GATE[55, 51]
# RY[55]
# RY[33]
# RX[33]
# RX[41]
# TWO_QUBIT_MS_GATE[33, 41]
# RY[33]
# RY[12]
# RX[12]
# RX[22]
# TWO_QUBIT_MS_GATE[12, 22]
# RY[12]
# RY[46]
# RX[46]
# RX[44]
# TWO_QUBIT_MS_GATE[46, 44]
# RY[46]
# RY[29]
# RX[29]
# RX[42]
# TWO_QUBIT_MS_GATE[29, 42]
# RY[29]
# RY[61]
# RX[61]
# RX[63]
# TWO_QUBIT_MS_GATE[61, 63]
# RY[61]
# RY[9]
# RX[9]
# RX[23]
# TWO_QUBIT_MS_GATE[9, 23]
# RY[9]
# RY[54]
# RX[54]
# RX[45]
# TWO_QUBIT_MS_GATE[54, 45]
# RY[54]
# RY[32]
# RX[32]
# RX[36]
# TWO_QUBIT_MS_GATE[32, 36]
# RY[32]
# RY[65]
# RX[65]
# RX[67]
# TWO_QUBIT_MS_GATE[65, 67]
# RY[65]
# RY[30]
# RX[30]
# RX[18]
# TWO_QUBIT_MS_GATE[30, 18]
# RY[30]
# RY[62]
# RX[62]
# RX[51]
# TWO_QUBIT_MS_GATE[62, 51]
# RY[62]
# RY[55]
# RX[55]
# RX[41]
# TWO_QUBIT_MS_GATE[55, 41]
# RY[55]
# RY[33]
# RX[33]
# RX[22]
# TWO_QUBIT_MS_GATE[33, 22]
# RY[33]
# RY[66]
# RX[66]
# RX[44]
# TWO_QUBIT_MS_GATE[66, 44]
# RY[66]
# RY[46]
# RX[46]
# RX[35]
# TWO_QUBIT_MS_GATE[46, 35]
# RY[46]
# RY[29]
# RX[29]
# RX[30]
# TWO_QUBIT_MS_GATE[29, 30]
# RY[29]
# RY[61]
# RX[61]
# RX[62]
# TWO_QUBIT_MS_GATE[61, 62]
# RY[61]
# RY[9]
# RX[9]
# RX[10]
# TWO_QUBIT_MS_GATE[9, 10]
# RY[9]
# RY[54]
# RX[54]
# RX[55]
# TWO_QUBIT_MS_GATE[54, 55]
# RY[54]
# RY[32]
# RX[32]
# RX[33]
# TWO_QUBIT_MS_GATE[32, 33]
# RY[32]
# RY[65]
# RX[65]
# RX[66]
# TWO_QUBIT_MS_GATE[65, 66]
# RY[65]
# RY[19]
# RX[19]
# RX[18]
# TWO_QUBIT_MS_GATE[19, 18]
# RY[19]
# RY[52]
# RX[52]
# RX[51]
# TWO_QUBIT_MS_GATE[52, 51]
# RY[52]
# RY[42]
# RX[42]
# RX[41]
# TWO_QUBIT_MS_GATE[42, 41]
# RY[42]
# RY[23]
# RX[23]
# RX[22]
# TWO_QUBIT_MS_GATE[23, 22]
# RY[23]
# RY[45]
# RX[45]
# RX[44]
# TWO_QUBIT_MS_GATE[45, 44]
# RY[45]
# RY[36]
# RX[36]
# RX[35]
# TWO_QUBIT_MS_GATE[36, 35]
# RY[36]
# RY[17]
# RX[17]
# RY[21]
# RX[21]
# RY[9]
# RX[9]
# RY[29]
# RX[29]
# RY[32]
# RX[32]
# RY[54]
# RX[54]
# RY[61]
# RX[61]
# RY[65]
# RX[65]
# MEASUREMENT[17]
# MEASUREMENT[21]
# MEASUREMENT[18]
# MEASUREMENT[9]
# MEASUREMENT[22]
# MEASUREMENT[28]
# MEASUREMENT[29]
# MEASUREMENT[41]
# MEASUREMENT[32]
# MEASUREMENT[35]
# MEASUREMENT[51]
# MEASUREMENT[54]
# MEASUREMENT[44]
# MEASUREMENT[61]
# MEASUREMENT[65]
# QUBIT_RESET[17]
# QUBIT_RESET[21]
# QUBIT_RESET[18]
# QUBIT_RESET[9]
# QUBIT_RESET[22]
# QUBIT_RESET[28]
# QUBIT_RESET[29]
# QUBIT_RESET[41]
# QUBIT_RESET[32]
# QUBIT_RESET[35]
# QUBIT_RESET[51]
# QUBIT_RESET[54]
# QUBIT_RESET[44]
# QUBIT_RESET[61]
# QUBIT_RESET[65]
# MEASUREMENT[19]
# MEASUREMENT[10]
# MEASUREMENT[23]
# MEASUREMENT[12]
# MEASUREMENT[30]
# MEASUREMENT[42]
# MEASUREMENT[33]
# MEASUREMENT[36]
# MEASUREMENT[52]
# MEASUREMENT[55]
# MEASUREMENT[45]
# MEASUREMENT[46]
# MEASUREMENT[62]
# MEASUREMENT[63]
# MEASUREMENT[66]
# MEASUREMENT[67]
# <svg viewBox="0 0 2400 2848"  version="1.1" xmlns="http://www.w3.org/2000/svg">
# <g id="qubit_lines">
# <path id="qubit_line:0" d="M64,64 L2368,64 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="64">q0</text>
# <path id="qubit_line:1" d="M64,128 L2368,128 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="128">q1</text>
# <path id="qubit_line:2" d="M64,192 L2368,192 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="192">q2</text>
# <path id="qubit_line:3" d="M64,256 L2368,256 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="256">q3</text>
# <path id="qubit_line:4" d="M64,320 L2368,320 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="320">q4</text>
# <path id="qubit_line:5" d="M64,384 L2368,384 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="384">q5</text>
# <path id="qubit_line:6" d="M64,448 L2368,448 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="448">q6</text>
# <path id="qubit_line:7" d="M64,512 L2368,512 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="512">q7</text>
# <path id="qubit_line:8" d="M64,576 L2368,576 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="576">q8</text>
# <path id="qubit_line:9" d="M64,640 L2368,640 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="640">q9</text>
# <path id="qubit_line:10" d="M64,704 L2368,704 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="704">q10</text>
# <path id="qubit_line:11" d="M64,768 L2368,768 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="768">q11</text>
# <path id="qubit_line:12" d="M64,832 L2368,832 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="832">q12</text>
# <path id="qubit_line:13" d="M64,896 L2368,896 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="896">q13</text>
# <path id="qubit_line:14" d="M64,960 L2368,960 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="960">q14</text>
# <path id="qubit_line:15" d="M64,1024 L2368,1024 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1024">q15</text>
# <path id="qubit_line:16" d="M64,1088 L2368,1088 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1088">q16</text>
# <path id="qubit_line:17" d="M64,1152 L2368,1152 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1152">q17</text>
# <path id="qubit_line:18" d="M64,1216 L2368,1216 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1216">q18</text>
# <path id="qubit_line:19" d="M64,1280 L2368,1280 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1280">q19</text>
# <path id="qubit_line:20" d="M64,1344 L2368,1344 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1344">q20</text>
# <path id="qubit_line:21" d="M64,1408 L2368,1408 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1408">q21</text>
# <path id="qubit_line:22" d="M64,1472 L2368,1472 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1472">q22</text>
# <path id="qubit_line:23" d="M64,1536 L2368,1536 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1536">q23</text>
# <path id="qubit_line:24" d="M64,1600 L2368,1600 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1600">q24</text>
# <path id="qubit_line:25" d="M64,1664 L2368,1664 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1664">q25</text>
# <path id="qubit_line:26" d="M64,1728 L2368,1728 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1728">q26</text>
# <path id="qubit_line:27" d="M64,1792 L2368,1792 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1792">q27</text>
# <path id="qubit_line:28" d="M64,1856 L2368,1856 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1856">q28</text>
# <path id="qubit_line:29" d="M64,1920 L2368,1920 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1920">q29</text>
# <path id="qubit_line:30" d="M64,1984 L2368,1984 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1984">q30</text>
# <path id="qubit_line:31" d="M64,2048 L2368,2048 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="2048">q31</text>
# <path id="qubit_line:32" d="M64,2112 L2368,2112 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="2112">q32</text>
# <path id="qubit_line:33" d="M64,2176 L2368,2176 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="2176">q33</text>
# <path id="qubit_line:34" d="M64,2240 L2368,2240 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="2240">q34</text>
# <path id="qubit_line:35" d="M64,2304 L2368,2304 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="2304">q35</text>
# <path id="qubit_line:36" d="M64,2368 L2368,2368 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="2368">q36</text>
# <path id="qubit_line:37" d="M64,2432 L2368,2432 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="2432">q37</text>
# <path id="qubit_line:38" d="M64,2496 L2368,2496 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="2496">q38</text>
# <path id="qubit_line:39" d="M64,2560 L2368,2560 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="2560">q39</text>
# <path id="qubit_line:40" d="M64,2624 L2368,2624 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="2624">q40</text>
# <path id="qubit_line:41" d="M64,2688 L2368,2688 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="2688">q41</text>
# <path id="qubit_line:42" d="M64,2752 L2368,2752 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="2752">q42</text>
# </g>
# <rect x="80" y="112" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="128">COORDS(1,1)</text>
# <rect x="80" y="176" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="192">COORDS(2,0)</text>
# <rect x="80" y="240" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="256">COORDS(3,1)</text>
# <rect x="80" y="368" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="384">COORDS(5,1)</text>
# <rect x="80" y="432" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="448">COORDS(6,0)</text>
# <rect x="80" y="496" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="512">COORDS(7,1)</text>
# <rect x="80" y="688" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="704">COORDS(1,3)</text>
# <rect x="80" y="752" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="768">COORDS(2,2)</text>
# <rect x="80" y="816" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="832">COORDS(3,3)</text>
# <rect x="80" y="880" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="896">COORDS(4,2)</text>
# <rect x="80" y="944" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="960">COORDS(5,3)</text>
# <rect x="80" y="1008" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="1024">COORDS(6,2)</text>
# <rect x="80" y="1072" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="1088">COORDS(7,3)</text>
# <rect x="80" y="1200" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="1216">COORDS(0,4)</text>
# <rect x="80" y="1264" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="1280">COORDS(1,5)</text>
# <rect x="80" y="1328" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="1344">COORDS(2,4)</text>
# <rect x="80" y="1392" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="1408">COORDS(3,5)</text>
# <rect x="80" y="1456" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="1472">COORDS(4,4)</text>
# <rect x="80" y="1520" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="1536">COORDS(5,5)</text>
# <rect x="80" y="1584" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="1600">COORDS(6,4)</text>
# <rect x="80" y="1648" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="1664">COORDS(7,5)</text>
# <rect x="80" y="1712" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="1728">COORDS(8,4)</text>
# <rect x="80" y="1840" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="1856">COORDS(1,7)</text>
# <rect x="80" y="1904" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="1920">COORDS(2,6)</text>
# <rect x="80" y="1968" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="1984">COORDS(3,7)</text>
# <rect x="80" y="2032" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="2048">COORDS(4,6)</text>
# <rect x="80" y="2096" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="2112">COORDS(5,7)</text>
# <rect x="80" y="2160" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="2176">COORDS(6,6)</text>
# <rect x="80" y="2224" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="2240">COORDS(7,7)</text>
# <rect x="80" y="2480" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="2496">COORDS(2,8)</text>
# <rect x="80" y="2736" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="2752">COORDS(6,8)</text>
# <rect x="336" y="112" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="128" fill="white">R</text>
# <rect x="336" y="240" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="256" fill="white">R</text>
# <rect x="336" y="368" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="384" fill="white">R</text>
# <rect x="336" y="496" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="512" fill="white">R</text>
# <rect x="336" y="688" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="704" fill="white">R</text>
# <rect x="336" y="816" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="832" fill="white">R</text>
# <rect x="336" y="944" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="960" fill="white">R</text>
# <rect x="336" y="1072" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="1088" fill="white">R</text>
# <rect x="336" y="1264" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="1280" fill="white">R</text>
# <rect x="336" y="1392" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="1408" fill="white">R</text>
# <rect x="336" y="1520" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="1536" fill="white">R</text>
# <rect x="336" y="1648" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="1664" fill="white">R</text>
# <rect x="336" y="1840" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="1856" fill="white">R</text>
# <rect x="336" y="1968" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="1984" fill="white">R</text>
# <rect x="336" y="2096" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="2112" fill="white">R</text>
# <rect x="336" y="2224" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="2240" fill="white">R</text>
# <rect x="336" y="176" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="192" fill="white">R</text>
# <rect x="336" y="432" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="448" fill="white">R</text>
# <rect x="336" y="752" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="768" fill="white">R</text>
# <rect x="336" y="880" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="896" fill="white">R</text>
# <rect x="336" y="1008" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="1024" fill="white">R</text>
# <rect x="336" y="1200" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="1216" fill="white">R</text>
# <rect x="336" y="1328" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="1344" fill="white">R</text>
# <rect x="336" y="1456" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="1472" fill="white">R</text>
# <rect x="336" y="1584" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="1600" fill="white">R</text>
# <rect x="336" y="1712" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="1728" fill="white">R</text>
# <rect x="336" y="1904" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="1920" fill="white">R</text>
# <rect x="336" y="2032" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x
</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2144" y="748">D8 = rec[20]*rec[19]*rec[16]*rec[15]*rec[2]</text>
# <rect x="1936" y="1904" width="416" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="2144" y="1920">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="2144" y="1940">coords=(2,6,1)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2144" y="1900">D9 = rec[28]*rec[27]*rec[24]*rec[23]*rec[10]</text>
# <rect x="1936" y="1456" width="416" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="2144" y="1472">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="2144" y="1492">coords=(4,4,1)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2144" y="1452">D10 = rec[25]*rec[24]*rec[21]*rec[20]*rec[7]</text>
# <rect x="1936" y="1008" width="416" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="2144" y="1024">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="2144" y="1044">coords=(6,2,1)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2144" y="1004">D11 = rec[22]*rec[21]*rec[18]*rec[17]*rec[4]</text>
# <rect x="1936" y="2160" width="416" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="2144" y="2176">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="2144" y="2196">coords=(6,6,1)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2144" y="2156">D12 = rec[30]*rec[29]*rec[26]*rec[25]*rec[12]</text>
# <rect x="1936" y="1712" width="288" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="2080" y="1728">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="2080" y="1748">coords=(8,4,1)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2080" y="1708">D13 = rec[26]*rec[22]*rec[9]</text>
# <rect x="1936" y="112" width="352" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="2112" y="128">OBS_INCLUDE(0)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2112" y="108">L0 *= rec[18]*rec[17]*rec[16]*rec[15]</text>
# <path d="M1604,40 L1604,32 L2364,32 L2364,40 " stroke="black" fill="none"/>
# <path d="M1604,2808 L1604,2816 L2364,2816 L2364,2808 " stroke="black" fill="none"/>
# </svg>

# %%
from src.simulator.qccd_circuit import *
noise = 1e-3
d=3
    
circuit = QCCDCircuit.generated(
    "color_code:memory_xyz",
    rounds=2,
    distance=d,
    after_clifford_depolarization=noise,
    after_reset_flip_probability=noise,
    before_measure_flip_probability=noise,
    before_round_data_depolarization=noise,
)


rows = 4
cols = 4
capacity = 4

print(circuit.circuitString())
arch, (instructions,_) = circuit.processCircuitAugmentedGrid(rows=rows, cols=cols, trapCapacity=capacity)

for i in instructions:
    print(i.label+str([ion.idx for ion in i.ions]))

_capacities = [2,3]
rows = 10
cols = 10

label='part'
fig, axs = plt.subplots(1, len(_capacities))
for ax, capacity in zip(axs, _capacities):
    arch1, (instructions,_) = circuit.processCircuitAugmentedGrid(rows=rows, cols=cols, trapCapacity=capacity)
    arch1.ION_SIZE = 2000

    for idx, (ion, pos) in circuit._ionMapping.items():
        ion.set(ion.idx, pos[0], pos[1])

    arch1.refreshGraph()
    edgesDups = []
    edgesPos = []
    ionsInvolved = set()
    score = 0
    for op in instructions:
        if not isinstance(op, TwoQubitMSGate):
            continue
        if not ionsInvolved.isdisjoint(op.ions):
            score+=1
            ionsInvolved=set()
        edgesDups.append((op.ions, score))
        edgesPos.append((op.ionsActedIdxs, score))
        ionsInvolved=ionsInvolved.union(op.ions)
    scores = [score for ((ion1,ion2), score) in edgesDups]
    color_from_score = {s: (5+i*i)*2 for i, s in enumerate( sorted(list(set(scores)), reverse=True))}
    arch1._manipulationTraps.append(([(ion1.idx, ion2.idx) for ((ion1,ion2), score) in edgesDups], [color_from_score[score] for ((ion1,ion2), score) in edgesDups]))
    arch1.display(fig, ax, showLabels=False, showEdges=False, show_junction=False)
    ax.set_title(f"{label} {_capacities}")


circuit.without_noise().diagram('timeline-svg')
# Out:
# ['QUBIT_COORDS(0, 0) 0', 'QUBIT_COORDS(1, 0) 1', 'QUBIT_COORDS(2, 0) 2', 'QUBIT_COORDS(3, 0) 3', 'QUBIT_COORDS(0.5, 1) 4', 'QUBIT_COORDS(1.5, 1) 5', 'QUBIT_COORDS(2.5, 1) 6', 'QUBIT_COORDS(1, 2) 7', 'QUBIT_COORDS(2, 2) 8', 'QUBIT_COORDS(1.5, 3) 9', 'R 0', 'R 1', 'R 2', 'R 3', 'R 4', 'R 5', 'R 6', 'R 7', 'R 8', 'R 9', 'S 0 1 3 5 6 7 9 0 1 3 5 6 7 9 0 1 3 5 6 7 9', 'H 0', 'H 1', 'H 3', 'H 5', 'H 6', 'H 7', 'H 9', 'CNOT 5 4', 'CNOT 3 2', 'BARRIER', 'CNOT 7 4', 'CNOT 6 2', 'BARRIER', 'CNOT 1 4', 'CNOT 6 8', 'BARRIER', 'CNOT 1 2', 'CNOT 7 8', 'BARRIER', 'CNOT 5 2', 'CNOT 9 8', 'BARRIER', 'CNOT 0 4', 'CNOT 5 8', 'BARRIER', 'M 2', 'M 4', 'M 8', 'R 2', 'R 4', 'R 8', 'S 0 1 3 5 6 7 9 0 1 3 5 6 7 9 0 1 3 5 6 7 9', 'H 0', 'H 1', 'H 3', 'H 5', 'H 6', 'H 7', 'H 9', 'CNOT 5 4', 'CNOT 3 2', 'BARRIER', 'CNOT 7 4', 'CNOT 6 2', 'BARRIER', 'CNOT 1 4', 'CNOT 6 8', 'BARRIER', 'CNOT 1 2', 'CNOT 7 8', 'BARRIER', 'CNOT 5 2', 'CNOT 9 8', 'BARRIER', 'CNOT 0 4', 'CNOT 5 8', 'BARRIER', 'M 2', 'M 4', 'M 8', 'R 2', 'R 4', 'R 8', 'S 0 1 3 5 6 7 9 0 1 3 5 6 7 9 0 1 3 5 6 7 9', 'H 0', 'H 1', 'H 3', 'H 5', 'H 6', 'H 7', 'H 9', 'M 0', 'M 1', 'M 3', 'M 5', 'M 6', 'M 7', 'M 9', 'H 0', 'H 1', 'H 3', 'H 5', 'H 6', 'H 7', 'H 9', 'S 0 1 3 5 6 7 9']
# C:\Users\monam\OneDrive\Desktop\UNI\II\PartIIProject\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\monam\OneDrive\Desktop\UNI\II\PartIIProject\.venv\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 21
#      18 capacity = 4
#      20 print(circuit.circuitString())
# ---> 21 arch, (instructions,_) = circuit.processCircuitAugmentedGrid(rows=rows, cols=cols, trapCapacity=capacity)
#      23 for i in instructions:
#      24     print(i.label+str([ion.idx for ion in i.ions]))
#
# File ~\OneDrive\Desktop\UNI\II\PartIIProject\CST-Part-II-Project-Code\src\simulator\qccd_circuit.py:336, in QCCDCircuit.processCircuitAugmentedGrid(self, trapCapacity, rows, cols, padding, dataQubitIdxs)
#     333 if (trapCapacity-1) * ((rows-1) * (2*cols-1)+cols) < len(self._ionMapping):
#     334     raise ValueError("processCircuit: not enough traps")
# --> 336 clusters=regularPartition(self._measurementIons, self._dataIons, trapCapacity)
#     338 cs, rs = cols, rows
#     339 allGridPos = []
#
# File ~\OneDrive\Desktop\UNI\II\PartIIProject\CST-Part-II-Project-Code\src\compiler\qccd_qubits_to_ions.py:62, in regularPartition(measurementIons, dataIons, trapCapacity)
#      60 clusters = list(clustersD)
#      61 for clusterM in clustersM:
# ---> 62     cl = min(clusters, key=lambda c: (c[1][0]-clusterM[1][0])**2+(c[1][1]-clusterM[1][1])**2)
#      63     cIons = list(cl[0])+list(clusterM[0])
#      64     rD = len(cl[0])/len(cIons)
#
# File ~\OneDrive\Desktop\UNI\II\PartIIProject\CST-Part-II-Project-Code\src\compiler\qccd_qubits_to_ions.py:62, in regularPartition.<locals>.<lambda>(c)
#      60 clusters = list(clustersD)
#      61 for clusterM in clustersM:
# ---> 62     cl = min(clusters, key=lambda c: (c[1][0]-clusterM[1][0])**2+(c[1][1]-clusterM[1][1])**2)
#      63     cIons = list(cl[0])+list(clusterM[0])
#      64     rD = len(cl[0])/len(cIons)
#
# IndexError: invalid index to scalar variable.

# %%
circuit = QCCDCircuit.generated(
    "color_code:memory_xyz",
    rounds=2, # One round is enough to show the layout
    distance=5,
    after_clifford_depolarization=1e-3
)
circuit.diagram(type='detector-slice-svg')

# %%
# %pip install svgwrite
# Out:
# Requirement already satisfied: svgwrite in c:\users\monam\onedrive\desktop\uni\ii\partiiproject\.venv\lib\site-packages (1.4.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from src.color_code_utils.color_code_circuits import color_code_circuit_666

cc = color_code_circuit_666.ColorCodeCircuit666(3,5)
cc.circuit
# Out:
# stim.Circuit('''
#     QUBIT_COORDS(0, 0) 0
#     QUBIT_COORDS(1, 1) 1
#     QUBIT_COORDS(2, 0) 2
#     QUBIT_COORDS(2, 2) 3
#     QUBIT_COORDS(3, 1) 4
#     QUBIT_COORDS(3, 3) 5
#     QUBIT_COORDS(4, 0) 6
#     QUBIT_COORDS(4, 2) 7
#     QUBIT_COORDS(5, 1) 8
#     QUBIT_COORDS(6, 0) 9
#     R 3 0 4 2 8 5 9 1 6 7
#     TICK
#     CX 1 2 7 8
#     TICK
#     CX 6 9 1 4
#     TICK
#     CX 1 0 7 4
#     TICK
#     CX 6 8 1 3
#     TICK
#     CX 6 2 7 3
#     TICK
#     CX 6 4 7 5
#     TICK
#     MRX 6 1 7
#     CX 2 1 8 7
#     TICK
#     CX 9 6 4 1
#     TICK
#     CX 0 1 4 7
#     TICK
#     CX 8 6 3 1
#     TICK
#     CX 2 6 3 7
#     TICK
#     CX 4 6 5 7
#     TICK
#     MR 6 1 7
#     DETECTOR(4, 0, 1, 3) rec[-3]
#     DETECTOR(1, 1, 1, 4) rec[-2]
#     DETECTOR(4, 2, 1, 5) rec[-1]
#     TICK
#     SHIFT_COORDS(0, 0, 1)
#     REPEAT 4 {
#         CX 1 2 7 8
#         TICK
#         CX 6 9 1 4
#         TICK
#         CX 1 0 7 4
#         TICK
#         CX 6 8 1 3
#         TICK
#         CX 6 2 7 3
#         TICK
#         CX 6 4 7 5
#         TICK
#         MRX 6 1 7
#         DETECTOR(4, 0, 0, 0) rec[-3] rec[-9]
#         DETECTOR(1, 1, 0, 1) rec[-2] rec[-8]
#         DETECTOR(4, 2, 0, 2) rec[-1] rec[-7]
#         TICK
#         CX 2 1 8 7
#         TICK
#         CX 9 6 4 1
#         TICK
#         CX 0 1 4 7
#         TICK
#         CX 8 6 3 1
#         TICK
#         CX 2 6 3 7
#         TICK
#         CX 4 6 5 7
#         TICK
#         MR 6 1 7
#         DETECTOR(4, 0, 1, 3) rec[-3] rec[-9]
#         DETECTOR(1, 1, 1, 4) rec[-2] rec[-8]
#         DETECTOR(4, 2, 1, 5) rec[-1] rec[-7]
#         TICK
#         SHIFT_COORDS(0, 0, 1)
#     }
#     M 0 2 3 4 5 8 9
#     DETECTOR(4, 0, 1, 3) rec[-1] rec[-2] rec[-4] rec[-6] rec[-10]
#     DETECTOR(1, 1, 1, 4) rec[-7] rec[-6] rec[-4] rec[-5] rec[-9]
#     DETECTOR(4, 2, 1, 5) rec[-4] rec[-2] rec[-3] rec[-5] rec[-8]
#     OBSERVABLE_INCLUDE(0) rec[-7] rec[-6] rec[-1]
# ''')

# %%
from src.simulator.qccd_circuit import *

noise = 1e-3
d=3
circuit1 = QCCDCircuit.generate_color_code(3,1,(6,6,6))
circuit = QCCDCircuit.generated(
    "surface_code:rotated_memory_z",
    rounds=2,
    distance=d,
    after_clifford_depolarization=noise,
    after_reset_flip_probability=noise,
    before_measure_flip_probability=noise,
    before_round_data_depolarization=noise,
)
rows = 4
cols = 4
capacity = 4
arch, (instructions,_) = circuit.processCircuitAugmentedGrid(rows=rows, cols=cols, trapCapacity=capacity)

for i in instructions:
    print(i.label+str([ion.idx for ion in i.ions]))
# Out:
# QUBIT_RESET[26]
# QUBIT_RESET[27]
# QUBIT_RESET[31]
# QUBIT_RESET[38]
# QUBIT_RESET[39]
# QUBIT_RESET[41]
# QUBIT_RESET[48]
# QUBIT_RESET[51]
# QUBIT_RESET[52]
# QUBIT_RESET[25]
# QUBIT_RESET[37]
# QUBIT_RESET[29]
# QUBIT_RESET[30]
# QUBIT_RESET[46]
# QUBIT_RESET[47]
# QUBIT_RESET[50]
# QUBIT_RESET[58]
# RY[25]
# RX[25]
# RY[29]
# RX[29]
# RY[47]
# RX[47]
# RY[58]
# RX[58]
# RY[25]
# RX[25]
# RX[27]
# TWO_QUBIT_MS_GATE[25, 27]
# RY[25]
# RY[47]
# RX[47]
# RX[51]
# TWO_QUBIT_MS_GATE[47, 51]
# RY[47]
# RY[29]
# RX[29]
# RX[41]
# TWO_QUBIT_MS_GATE[29, 41]
# RY[29]
# RY[48]
# RX[48]
# RX[46]
# TWO_QUBIT_MS_GATE[48, 46]
# RY[48]
# RY[39]
# RX[39]
# RX[37]
# TWO_QUBIT_MS_GATE[39, 37]
# RY[39]
# RY[52]
# RX[52]
# RX[50]
# TWO_QUBIT_MS_GATE[52, 50]
# RY[52]
# RY[25]
# RX[25]
# RX[26]
# TWO_QUBIT_MS_GATE[25, 26]
# RY[25]
# RY[47]
# RX[47]
# RX[48]
# TWO_QUBIT_MS_GATE[47, 48]
# RY[47]
# RY[29]
# RX[29]
# RX[39]
# TWO_QUBIT_MS_GATE[29, 39]
# RY[29]
# RY[38]
# RX[38]
# RX[46]
# TWO_QUBIT_MS_GATE[38, 46]
# RY[38]
# RY[27]
# RX[27]
# RX[37]
# TWO_QUBIT_MS_GATE[27, 37]
# RY[27]
# RY[41]
# RX[41]
# RX[50]
# TWO_QUBIT_MS_GATE[41, 50]
# RY[41]
# RY[47]
# RX[47]
# RX[39]
# TWO_QUBIT_MS_GATE[47, 39]
# RY[47]
# RY[29]
# RX[29]
# RX[31]
# TWO_QUBIT_MS_GATE[29, 31]
# RY[29]
# RY[58]
# RX[58]
# RX[52]
# TWO_QUBIT_MS_GATE[58, 52]
# RY[58]
# RY[38]
# RX[38]
# RX[37]
# TWO_QUBIT_MS_GATE[38, 37]
# RY[38]
# RY[51]
# RX[51]
# RX[50]
# TWO_QUBIT_MS_GATE[51, 50]
# RY[51]
# RY[41]
# RX[41]
# RX[30]
# TWO_QUBIT_MS_GATE[41, 30]
# RY[41]
# RY[47]
# RX[47]
# RX[38]
# TWO_QUBIT_MS_GATE[47, 38]
# RY[47]
# RY[29]
# RX[29]
# RX[27]
# TWO_QUBIT_MS_GATE[29, 27]
# RY[29]
# RY[58]
# RX[58]
# RX[51]
# TWO_QUBIT_MS_GATE[58, 51]
# RY[58]
# RY[26]
# RX[26]
# RX[37]
# TWO_QUBIT_MS_GATE[26, 37]
# RY[26]
# RY[39]
# RX[39]
# RX[50]
# TWO_QUBIT_MS_GATE[39, 50]
# RY[39]
# RY[31]
# RX[31]
# RX[30]
# TWO_QUBIT_MS_GATE[31, 30]
# RY[31]
# RY[25]
# RX[25]
# RY[29]
# RX[29]
# RY[47]
# RX[47]
# RY[58]
# RX[58]
# MEASUREMENT[25]
# MEASUREMENT[37]
# MEASUREMENT[29]
# MEASUREMENT[30]
# MEASUREMENT[46]
# MEASUREMENT[47]
# MEASUREMENT[50]
# MEASUREMENT[58]
# QUBIT_RESET[25]
# QUBIT_RESET[37]
# QUBIT_RESET[29]
# QUBIT_RESET[30]
# QUBIT_RESET[46]
# QUBIT_RESET[47]
# QUBIT_RESET[50]
# QUBIT_RESET[58]
# RY[25]
# RX[25]
# RY[29]
# RX[29]
# RY[47]
# RX[47]
# RY[58]
# RX[58]
# RY[25]
# RX[25]
# RX[27]
# TWO_QUBIT_MS_GATE[25, 27]
# RY[25]
# RY[47]
# RX[47]
# RX[51]
# TWO_QUBIT_MS_GATE[47, 51]
# RY[47]
# RY[29]
# RX[29]
# RX[41]
# TWO_QUBIT_MS_GATE[29, 41]
# RY[29]
# RY[48]
# RX[48]
# RX[46]
# TWO_QUBIT_MS_GATE[48, 46]
# RY[48]
# RY[39]
# RX[39]
# RX[37]
# TWO_QUBIT_MS_GATE[39, 37]
# RY[39]
# RY[52]
# RX[52]
# RX[50]
# TWO_QUBIT_MS_GATE[52, 50]
# RY[52]
# RY[25]
# RX[25]
# RX[26]
# TWO_QUBIT_MS_GATE[25, 26]
# RY[25]
# RY[47]
# RX[47]
# RX[48]
# TWO_QUBIT_MS_GATE[47, 48]
# RY[47]
# RY[29]
# RX[29]
# RX[39]
# TWO_QUBIT_MS_GATE[29, 39]
# RY[29]
# RY[38]
# RX[38]
# RX[46]
# TWO_QUBIT_MS_GATE[38, 46]
# RY[38]
# RY[27]
# RX[27]
# RX[37]
# TWO_QUBIT_MS_GATE[27, 37]
# RY[27]
# RY[41]
# RX[41]
# RX[50]
# TWO_QUBIT_MS_GATE[41, 50]
# RY[41]
# RY[47]
# RX[47]
# RX[39]
# TWO_QUBIT_MS_GATE[47, 39]
# RY[47]
# RY[29]
# RX[29]
# RX[31]
# TWO_QUBIT_MS_GATE[29, 31]
# RY[29]
# RY[58]
# RX[58]
# RX[52]
# TWO_QUBIT_MS_GATE[58, 52]
# RY[58]
# RY[38]
# RX[38]
# RX[37]
# TWO_QUBIT_MS_GATE[38, 37]
# RY[38]
# RY[51]
# RX[51]
# RX[50]
# TWO_QUBIT_MS_GATE[51, 50]
# RY[51]
# RY[41]
# RX[41]
# RX[30]
# TWO_QUBIT_MS_GATE[41, 30]
# RY[41]
# RY[47]
# RX[47]
# RX[38]
# TWO_QUBIT_MS_GATE[47, 38]
# RY[47]
# RY[29]
# RX[29]
# RX[27]
# TWO_QUBIT_MS_GATE[29, 27]
# RY[29]
# RY[58]
# RX[58]
# RX[51]
# TWO_QUBIT_MS_GATE[58, 51]
# RY[58]
# RY[26]
# RX[26]
# RX[37]
# TWO_QUBIT_MS_GATE[26, 37]
# RY[26]
# RY[39]
# RX[39]
# RX[50]
# TWO_QUBIT_MS_GATE[39, 50]
# RY[39]
# RY[31]
# RX[31]
# RX[30]
# TWO_QUBIT_MS_GATE[31, 30]
# RY[31]
# RY[25]
# RX[25]
# RY[29]
# RX[29]
# RY[47]
# RX[47]
# RY[58]
# RX[58]
# MEASUREMENT[25]
# MEASUREMENT[37]
# MEASUREMENT[29]
# MEASUREMENT[30]
# MEASUREMENT[46]
# MEASUREMENT[47]
# MEASUREMENT[50]
# MEASUREMENT[58]
# QUBIT_RESET[25]
# QUBIT_RESET[37]
# QUBIT_RESET[29]
# QUBIT_RESET[30]
# QUBIT_RESET[46]
# QUBIT_RESET[47]
# QUBIT_RESET[50]
# QUBIT_RESET[58]
# MEASUREMENT[26]
# MEASUREMENT[27]
# MEASUREMENT[31]
# MEASUREMENT[38]
# MEASUREMENT[39]
# MEASUREMENT[41]
# MEASUREMENT[48]
# MEASUREMENT[51]
# MEASUREMENT[52]

# %%
_capacities = [2,3]
rows = 10
cols = 10

label='part'
fig, axs = plt.subplots(1, len(_capacities))
for ax, capacity in zip(axs, _capacities):
    arch1, (instructions,_) = circuit.processCircuitAugmentedGrid(rows=rows, cols=cols, trapCapacity=capacity)
    arch1.ION_SIZE = 2000

    for idx, (ion, pos) in circuit._ionMapping.items():
        ion.set(ion.idx, pos[0], pos[1])

    arch1.refreshGraph()
    edgesDups = []
    edgesPos = []
    ionsInvolved = set()
    score = 0
    for op in instructions:
        if not isinstance(op, TwoQubitMSGate):
            continue
        if not ionsInvolved.isdisjoint(op.ions):
            score+=1
            ionsInvolved=set()
        edgesDups.append((op.ions, score))
        edgesPos.append((op.ionsActedIdxs, score))
        ionsInvolved=ionsInvolved.union(op.ions)
    #print(edgesDups)
    scores = [score for ((ion1,ion2), score) in edgesDups]
    color_from_score = {s: i for i, s in enumerate( sorted(list(set(scores)), reverse=True))}
    #print(color_from_score)
    arch1._manipulationTraps.append(([(ion1.idx, ion2.idx) for ((ion1,ion2), score) in edgesDups], [color_from_score[score] for ((ion1,ion2), score) in edgesDups]))
    arch1.display(fig, ax, showLabels=False, showEdges=False, show_junction=False)
    ax.set_title(f"{label} {_capacities}")


circuit.without_noise().diagram('timeline-svg')
# Out:
# <svg viewBox="0 0 3168 1760"  version="1.1" xmlns="http://www.w3.org/2000/svg">
# <g id="qubit_lines">
# <path id="qubit_line:0" d="M64,64 L3136,64 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="64">q0</text>
# <path id="qubit_line:1" d="M64,128 L3136,128 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="128">q1</text>
# <path id="qubit_line:2" d="M64,192 L3136,192 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="192">q2</text>
# <path id="qubit_line:3" d="M64,256 L3136,256 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="256">q3</text>
# <path id="qubit_line:4" d="M64,320 L3136,320 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="320">q4</text>
# <path id="qubit_line:5" d="M64,384 L3136,384 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="384">q5</text>
# <path id="qubit_line:6" d="M64,448 L3136,448 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="448">q6</text>
# <path id="qubit_line:7" d="M64,512 L3136,512 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="512">q7</text>
# <path id="qubit_line:8" d="M64,576 L3136,576 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="576">q8</text>
# <path id="qubit_line:9" d="M64,640 L3136,640 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="640">q9</text>
# <path id="qubit_line:10" d="M64,704 L3136,704 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="704">q10</text>
# <path id="qubit_line:11" d="M64,768 L3136,768 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="768">q11</text>
# <path id="qubit_line:12" d="M64,832 L3136,832 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="832">q12</text>
# <path id="qubit_line:13" d="M64,896 L3136,896 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="896">q13</text>
# <path id="qubit_line:14" d="M64,960 L3136,960 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="960">q14</text>
# <path id="qubit_line:15" d="M64,1024 L3136,1024 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1024">q15</text>
# <path id="qubit_line:16" d="M64,1088 L3136,1088 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1088">q16</text>
# <path id="qubit_line:17" d="M64,1152 L3136,1152 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1152">q17</text>
# <path id="qubit_line:18" d="M64,1216 L3136,1216 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1216">q18</text>
# <path id="qubit_line:19" d="M64,1280 L3136,1280 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1280">q19</text>
# <path id="qubit_line:20" d="M64,1344 L3136,1344 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1344">q20</text>
# <path id="qubit_line:21" d="M64,1408 L3136,1408 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1408">q21</text>
# <path id="qubit_line:22" d="M64,1472 L3136,1472 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1472">q22</text>
# <path id="qubit_line:23" d="M64,1536 L3136,1536 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1536">q23</text>
# <path id="qubit_line:24" d="M64,1600 L3136,1600 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1600">q24</text>
# <path id="qubit_line:25" d="M64,1664 L3136,1664 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1664">q25</text>
# </g>
# <rect x="80" y="112" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="128">COORDS(1,1)</text>
# <rect x="80" y="176" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="192">COORDS(2,0)</text>
# <rect x="80" y="240" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="256">COORDS(3,1)</text>
# <rect x="80" y="368" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="384">COORDS(5,1)</text>
# <rect x="80" y="560" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="576">COORDS(1,3)</text>
# <rect x="80" y="624" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="640">COORDS(2,2)</text>
# <rect x="80" y="688" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="704">COORDS(3,3)</text>
# <rect x="80" y="752" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="768">COORDS(4,2)</text>
# <rect x="80" y="816" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="832">COORDS(5,3)</text>
# <rect x="80" y="880" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="896">COORDS(6,2)</text>
# <rect x="80" y="944" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="960">COORDS(0,4)</text>
# <rect x="80" y="1008" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="1024">COORDS(1,5)</text>
# <rect x="80" y="1072" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="1088">COORDS(2,4)</text>
# <rect x="80" y="1136" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="1152">COORDS(3,5)</text>
# <rect x="80" y="1200" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="1216">COORDS(4,4)</text>
# <rect x="80" y="1264" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="1280">COORDS(5,5)</text>
# <rect x="80" y="1648" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="1664">COORDS(4,6)</text>
# <rect x="336" y="112" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="128" fill="white">R</text>
# <rect x="336" y="240" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="256" fill="white">R</text>
# <rect x="336" y="368" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="384" fill="white">R</text>
# <rect x="336" y="560" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="576" fill="white">R</text>
# <rect x="336" y="688" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="704" fill="white">R</text>
# <rect x="336" y="816" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="832" fill="white">R</text>
# <rect x="336" y="1008" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="1024" fill="white">R</text>
# <rect x="336" y="1136" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="1152" fill="white">R</text>
# <rect x="336" y="1264" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="1280" fill="white">R</text>
# <rect x="336" y="176" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="192" fill="white">R</text>
# <rect x="336" y="624" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="640" fill="white">R</text>
# <rect x="336" y="752" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="768" fill="white">R</text>
# <rect x="336" y="880" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="896" fill="white">R</text>
# <rect x="336" y="944" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="960" fill="white">R</text>
# <rect x="336" y="1072" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="1088" fill="white">R</text>
# <rect x="336" y="1200" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="1216" fill="white">R</text>
# <rect x="336" y="1648" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="352" y="1664" fill="white">R</text>
# <path d="M68,40 L68,32 L380,32 L380,40 " stroke="black" fill="none"/>
# <path d="M68,1720 L68,1728 L380,1728 L380,1720 " stroke="black" fill="none"/>
# <rect x="400" y="176" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="416" y="192">H</text>
# <rect x="400" y="752" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="416" y="768">H</text>
# <rect x="400" y="1072" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="416" y="1088">H</text>
# <rect x="400" y="1648" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="416" y="1664">H</text>
# <path d="M480,192 L480,256 " stroke="black"/>
# <circle cx="480" cy="192" r="12" stroke="none" fill="black"/>
# <circle cx="480" cy="256" r="12" stroke="black" fill="white"/>
# <path d="M468,256 L492,256 M480,244 L480,268 " stroke="black"/>
# <path d="M480,1088 L480,1152 " stroke="black"/>
# <circle cx="480" cy="1088" r="12" stroke="none" fill="black"/>
# <circle cx="480" cy="1152" r="12" stroke="black" fill="white"/>
# <path d="M468,1152 L492,1152 M480,1140 L480,1164 " stroke="black"/>
# <path d="M480,768 L480,832 " stroke="black"/>
# <circle cx="480" cy="768" r="12" stroke="none" fill="black"/>
# <circle cx="480" cy="832" r="12" stroke="black" fill="white"/>
# <path d="M468,832 L492,832 M480,820 L480,844 " stroke="black"/>
# <path d="M480,960 L480,1024 " stroke="black"/>
# <circle cx="480" cy="1024" r="12" stroke="none" fill="black"/>
# <circle cx="480" cy="960" r="12" stroke="black" fill="white"/>
# <path d="M468,960 L492,960 M480,948 L480,972 " stroke="black"/>
# <path d="M480,640 L480,704 " stroke="black"/>
# <circle cx="480" cy="704" r="12" stroke="none" fill="black"/>
width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="24" x="2400" y="1664" fill="white">MR</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2400" y="1644">rec[15]</text>
# <rect x="2448" y="176" width="224" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="2560" y="192">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="2560" y="212">coords=(2,0,1)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2560" y="172">D4 = rec[8]*rec[0]</text>
# <rect x="2448" y="624" width="224" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="2560" y="640">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="2560" y="660">coords=(2,2,1)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2560" y="620">D5 = rec[9]*rec[1]</text>
# <rect x="2448" y="752" width="224" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="2560" y="768">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="2560" y="788">coords=(4,2,1)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2560" y="748">D6 = rec[10]*rec[2]</text>
# <rect x="2448" y="880" width="224" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="2560" y="896">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="2560" y="916">coords=(6,2,1)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2560" y="876">D7 = rec[11]*rec[3]</text>
# <rect x="2448" y="944" width="224" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="2560" y="960">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="2560" y="980">coords=(0,4,1)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2560" y="940">D8 = rec[12]*rec[4]</text>
# <rect x="2448" y="1072" width="224" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="2560" y="1088">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="2560" y="1108">coords=(2,4,1)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2560" y="1068">D9 = rec[13]*rec[5]</text>
# <rect x="2448" y="1200" width="224" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="2560" y="1216">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="2560" y="1236">coords=(4,4,1)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2560" y="1196">D10 = rec[14]*rec[6]</text>
# <rect x="2448" y="1648" width="224" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="2560" y="1664">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="2560" y="1684">coords=(4,6,1)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2560" y="1644">D11 = rec[15]*rec[7]</text>
# <rect x="2448" y="112" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="2464" y="128" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2464" y="108">rec[16]</text>
# <rect x="2448" y="240" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="2464" y="256" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2464" y="236">rec[17]</text>
# <rect x="2448" y="368" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="2464" y="384" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2464" y="364">rec[18]</text>
# <rect x="2448" y="560" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="2464" y="576" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2464" y="556">rec[19]</text>
# <rect x="2448" y="688" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="2464" y="704" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2464" y="684">rec[20]</text>
# <rect x="2448" y="816" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="2464" y="832" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2464" y="812">rec[21]</text>
# <rect x="2448" y="1008" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="2464" y="1024" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2464" y="1004">rec[22]</text>
# <rect x="2448" y="1136" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="2464" y="1152" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2464" y="1132">rec[23]</text>
# <rect x="2448" y="1264" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="2464" y="1280" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2464" y="1260">rec[24]</text>
# <rect x="2704" y="944" width="288" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="2848" y="960">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="2848" y="980">coords=(0,4,2)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2848" y="940">D12 = rec[22]*rec[19]*rec[12]</text>
# <rect x="2704" y="624" width="416" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="2912" y="640">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="2912" y="660">coords=(2,2,2)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2912" y="620">D13 = rec[20]*rec[19]*rec[17]*rec[16]*rec[9]</text>
# <rect x="2704" y="1200" width="416" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="2912" y="1216">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="2912" y="1236">coords=(4,4,2)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2912" y="1196">D14 = rec[24]*rec[23]*rec[21]*rec[20]*rec[14]</text>
# <rect x="2704" y="880" width="288" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="2848" y="896">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="2848" y="916">coords=(6,2,2)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2848" y="876">D15 = rec[21]*rec[18]*rec[11]</text>
# <rect x="2704" y="112" width="288" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="2848" y="128">OBS_INCLUDE(0)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2848" y="108">L0 *= rec[18]*rec[17]*rec[16]</text>
# <path d="M2372,40 L2372,32 L3132,32 L3132,40 " stroke="black" fill="none"/>
# <path d="M2372,1720 L2372,1728 L3132,1728 L3132,1720 " stroke="black" fill="none"/>
# </svg>

# %%
noise=0.01
rounds=1
distance =6
trapCapacity=20
rows=1
cols=20

circuit = QCCDCircuit()
for i in range(2*distance-1):
    circuit+=QCCDCircuit(f"QUBIT_COORDS({i},0) {i}")
circuit += QCCDCircuit.generated(
    "repetition_code:memory",
    rounds=rounds,
    distance=distance,
    after_clifford_depolarization=noise,
    after_reset_flip_probability=noise,
    before_measure_flip_probability=noise,
    before_round_data_depolarization=noise,
)
circuit.without_noise().diagram('timeslice-svg')
# Out:
# <svg viewBox="0 0 1680 336"  version="1.1" xmlns="http://www.w3.org/2000/svg">
# <g id="qubit_dots">
# <circle id="qubit_dot:0:0_0:0" cx="80" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:1:1_0:0" cx="144" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:2:2_0:0" cx="208" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:3:3_0:0" cx="272" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:4:4_0:0" cx="336" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:5:5_0:0" cx="400" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:6:6_0:0" cx="464" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:7:7_0:0" cx="528" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:8:8_0:0" cx="592" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:9:9_0:0" cx="656" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:10:10_0:0" cx="720" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:0:0_0:0" cx="80" cy="256" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:1:1_0:0" cx="144" cy="256" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:2:2_0:0" cx="208" cy="256" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:3:3_0:0" cx="272" cy="256" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:4:4_0:0" cx="336" cy="256" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:5:5_0:0" cx="400" cy="256" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:6:6_0:0" cx="464" cy="256" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:7:7_0:0" cx="528" cy="256" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:8:8_0:0" cx="592" cy="256" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:9:9_0:0" cx="656" cy="256" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:10:10_0:0" cx="720" cy="256" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:0:0_0:1" cx="960" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:1:1_0:1" cx="1024" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:2:2_0:1" cx="1088" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:3:3_0:1" cx="1152" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:4:4_0:1" cx="1216" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:5:5_0:1" cx="1280" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:6:6_0:1" cx="1344" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:7:7_0:1" cx="1408" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:8:8_0:1" cx="1472" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:9:9_0:1" cx="1536" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:10:10_0:1" cx="1600" cy="80" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:0:0_0:1" cx="960" cy="256" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:1:1_0:1" cx="1024" cy="256" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:2:2_0:1" cx="1088" cy="256" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:3:3_0:1" cx="1152" cy="256" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:4:4_0:1" cx="1216" cy="256" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:5:5_0:1" cx="1280" cy="256" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:6:6_0:1" cx="1344" cy="256" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:7:7_0:1" cx="1408" cy="256" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:8:8_0:1" cx="1472" cy="256" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:9:9_0:1" cx="1536" cy="256" r="2" stroke="none" fill="black"/>
# <circle id="qubit_dot:10:10_0:1" cx="1600" cy="256" r="2" stroke="none" fill="black"/>
# </g>
# <rect x="64" y="64" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="80" y="80" fill="white">R</text>
# <rect x="128" y="64" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="144" y="80" fill="white">R</text>
# <rect x="192" y="64" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="208" y="80" fill="white">R</text>
# <rect x="256" y="64" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="272" y="80" fill="white">R</text>
# <rect x="320" y="64" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="336" y="80" fill="white">R</text>
# <rect x="384" y="64" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="400" y="80" fill="white">R</text>
# <rect x="448" y="64" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="464" y="80" fill="white">R</text>
# <rect x="512" y="64" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="528" y="80" fill="white">R</text>
# <rect x="576" y="64" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="592" y="80" fill="white">R</text>
# <rect x="640" y="64" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="656" y="80" fill="white">R</text>
# <rect x="704" y="64" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="720" y="80" fill="white">R</text>
# <path d="M960,80 L1024,80 " fill="none" stroke="black" stroke-width="5"/>
# <circle cx="960" cy="80" r="12" stroke="none" fill="black"/>
# <circle cx="1024" cy="80" r="12" stroke="black" fill="white"/>
# <path d="M1012,80 L1036,80 M1024,68 L1024,92 " stroke="black"/>
# <path d="M1088,80 L1152,80 " fill="none" stroke="black" stroke-width="5"/>
# <circle cx="1088" cy="80" r="12" stroke="none" fill="black"/>
# <circle cx="1152" cy="80" r="12" stroke="black" fill="white"/>
# <path d="M1140,80 L1164,80 M1152,68 L1152,92 " stroke="black"/>
# <path d="M1216,80 L1280,80 " fill="none" stroke="black" stroke-width="5"/>
# <circle cx="1216" cy="80" r="12" stroke="none" fill="black"/>
# <circle cx="1280" cy="80" r="12" stroke="black" fill="white"/>
# <path d="M1268,80 L1292,80 M1280,68 L1280,92 " stroke="black"/>
# <path d="M1344,80 L1408,80 " fill="none" stroke="black" stroke-width="5"/>
# <circle cx="1344" cy="80" r="12" stroke="none" fill="black"/>
# <circle cx="1408" cy="80" r="12" stroke="black" fill="white"/>
# <path d="M1396,80 L1420,80 M1408,68 L1408,92 " stroke="black"/>
# <path d="M1472,80 L1536,80 " fill="none" stroke="black" stroke-width="5"/>
# <circle cx="1472" cy="80" r="12" stroke="none" fill="black"/>
# <circle cx="1536" cy="80" r="12" stroke="black" fill="white"/>
# <path d="M1524,80 L1548,80 M1536,68 L1536,92 " stroke="black"/>
# <path d="M208,256 L144,256 " fill="none" stroke="black" stroke-width="5"/>
# <circle cx="208" cy="256" r="12" stroke="none" fill="black"/>
# <circle cx="144" cy="256" r="12" stroke="black" fill="white"/>
# <path d="M132,256 L156,256 M144,244 L144,268 " stroke="black"/>
# <path d="M336,256 L272,256 " fill="none" stroke="black" stroke-width="5"/>
# <circle cx="336" cy="256" r="12" stroke="none" fill="black"/>
# <circle cx="272" cy="256" r="12" stroke="black" fill="white"/>
# <path d="M260,256 L284,256 M272,244 L272,268 " stroke="black"/>
# <path d="M464,256 L400,256 " fill="none" stroke="black" stroke-width="5"/>
# <circle cx="464" cy="256" r="12" stroke="none" fill="black"/>
# <circle cx="400" cy="256" r="12" stroke="black" fill="white"/>
# <path d="M388,256 L412,256 M400,244 L400,268 " stroke="black"/>
# <path d="M592,256 L528,256 " fill="none" stroke="black" stroke-width="5"/>
# <circle cx="592" cy="256" r="12" stroke="none" fill="black"/>
# <circle cx="528" cy="256" r="12" stroke="black" fill="white"/>
# <path d="M516,256 L540,256 M528,244 L528,268 " stroke="black"/>
# <path d="M720,256 L656,256 " fill="none" stroke="black" stroke-width="5"/>
# <circle cx="720" cy="256" r="12" stroke="none" fill="black"/>
# <circle cx="656" cy="256" r="12" stroke="black" fill="white"/>
# <path d="M644,256 L668,256 M656,244 L656,268 " stroke="black"/>
# <rect x="1008" y="240" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="24" x="1024" y="256" fill="white">MR</text>
# <rect x="1136" y="240" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="24" x="1152" y="256" fill="white">MR</text>
# <rect x="1264" y="240" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="24" x="1280" y="256" fill="white">MR</text>
# <rect x="1392" y="240" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="24" x="1408" y="256" fill="white">MR</text>
# <rect x="1520" y="240" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="24" x="1536" y="256" fill="white">MR</text>
# <rect x="944" y="240" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="960" y="256" fill="white">M</text>
# <rect x="1072" y="240" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="1088" y="256" fill="white">M</text>
# <rect x="1200" y="240" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="1216" y="256" fill="white">M</text>
# <rect x="1328" y="240" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="1344" y="256" fill="white">M</text>
# <rect x="1456" y="240" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="1472" y="256" fill="white">M</text>
# <rect x="1584" y="240" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="1600" y="256" fill="white">M</text>
# <g id="tick_borders">
# <text dominant-baseline="hanging" text-anchor="middle" font-family="serif" font-size="18" transform="rotate(90)" x="80" y="-794">Tick 0</text>
# <rect id="tick_border:0:0_0:0" x="0" y="0" width="800" height="160" stroke="black" fill="none"/>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="serif" font-size="18" transform="rotate(90)" x="80" y="-1674">Tick 1</text>
# <rect id="tick_border:1:0_1:1" x="880" y="0" width="800" height="160" stroke="black" fill="none"/>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="serif" font-size="18" transform="rotate(90)" x="256" y="-794">Tick 2</text>
# <rect id="tick_border:2:1_0:2" x="0" y="176" width="800" height="160" stroke="black" fill="none"/>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="serif" font-size="18" transform="rotate(90)" x="256" y="-1674">Tick 3</text>
# <rect id="tick_border:3:1_1:3" x="880" y="176" width="800" height="160" stroke="black" fill="none"/>
# </g>
# </svg>

# %%
arch, (instructions,_) = circuit.processCircuitAugmentedGrid(rows=rows, cols=cols, trapCapacity=trapCapacity, padding=0)

oldPositions = {}
for idx, (ion, pos) in circuit._ionMapping.items():
    oldPositions[idx] = ion.pos
    ion.set(ion.idx, pos[0], pos[1], parent=ion.parent)

fig,ax =plt.subplots()
arch1 = arch
arch1.refreshGraph()
edgesDups = []
edgesPos = []
ionsInvolved = set()
score = 0
for op in instructions:
    if not isinstance(op, TwoQubitMSGate):
        continue
    if not ionsInvolved.isdisjoint(op.ions):
        score+=1
        ionsInvolved=set()
    edgesDups.append((op.ions, score))
    edgesPos.append((op.ionsActedIdxs, score))
    ionsInvolved=ionsInvolved.union(op.ions)
scores = [score for ((ion1,ion2), score) in edgesDups]
color_from_score = {s: (5+i*i)*0 for i, s in enumerate( sorted(list(set(scores)), reverse=True))}
arch1._manipulationTraps.append(([(ion1.idx, ion2.idx) for ((ion1,ion2), score) in edgesDups], [color_from_score[score] for ((ion1,ion2), score) in edgesDups]))
arch1.display(fig, ax, showLabels=False, showEdges=False, show_junction=False)
fig.set_size_inches(arch.WINDOW_SIZE[0]*0.6, arch.WINDOW_SIZE[1]*0.6)
arch1._manipulationTraps = arch1._manipulationTraps[:-1]
for idx, (ion, pos) in circuit._ionMapping.items():
    ion.set(ion.idx, oldPositions[idx][0], oldPositions[idx][1], parent=ion.parent)


arch.refreshGraph()

fig,ax =plt.subplots()
arch.display(fig, ax, showLabels=False)
fig.set_size_inches(arch.WINDOW_SIZE[0], arch.WINDOW_SIZE[1])

allOps, barriers = ionRouting(arch, instructions, trapCapacity=trapCapacity)
parallelOpsMap = paralleliseOperationsWithBarriers(allOps, barriers)
parallelOps = list(dict(parallelOpsMap).values())


numSplits = sum(1 for instr in allOps if isinstance(instr, Split))
numGateSwaps = sum(1 for instr in allOps if isinstance(instr, GateSwap))

print(f"total number of routing operations: {len(allOps)-len(instructions)}")
print(f"total number of operations: {len(allOps)}")
print(f"time for operations: {max(parallelOpsMap.keys())*1e6}")
print(f"num gate swaps: {numGateSwaps}")
print(f"num splits: {numSplits}")
# Out:
# total number of routing operations: 0
# total number of operations: 77
# time for operations: 5400.0
# num gate swaps: 0
# num splits: 0
